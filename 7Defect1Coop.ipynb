# %% [markdown]
# ## Tutorial: Using pd_exp to create experiments with Prisoner's Dilemma Tournaments
# This notebook walks through two different experimental setups to showcase the code functionality of the `pd_exp` module.

# %%
# Local modules to import
import pd_exp
from helper_funcs import partitions
from settings import player_names, stag

# Other Python modules used
import pandas as pd
from pathlib import Path
import time, json
# Out:
# <generator object partitions at 0x7f612900b780>

# %% [markdown]
# ### 7D + Bitter Cooperator (1, 0, 1, 1)

# %%
import axelrod as axl
players = ['Defector', 'Fourteen Defect', 'Stubborn Defect', 'Suspicious Tit For Tat', 'Sucker Defect', 'Two Defect', 'Win-Shift Lose-Stay',                'Bitter Cooperator']
part_list = list(partitions(players,8))
p = Path('7_defect_Bitter_Cooperator.txt')
p.touch()
with open(p, "w") as f:
    json.dump(part_list, f)

# %%
# part_list = part_list[:3] # Let's just consider 3 different teams
# part_list = [[('Cooperator', 'Defector'), ('Cooperator', 'Cooperator'), ('Defector', 'Defector')]]
print('Total count of teams: ',len(part_list))
print(part_list)
start_time = time.time()

print('Instantiate PD Experiments with different game types')
classic_pdExp = pd_exp.PdExp(part_list)
# stag_pdExp = pd_exp.PdExp(part_list,game_type=stag)

print('Running experiments and computing data')
classic_pdExp.run_experiments()
# stag_pdExp.run_experiments()

print('Save the data')
path = 'Data/Experiment2/'
classic_pdExp.save_data(path, 'ClassicPD_7D_Bitter_Cooperator')  # CHANGE file_name string when necessary
# stag_pdExp.save_data(path, 'StagHunt_4x3_12uniq_DEMO_RPST_5_1_0_3')  # CHANGE file_name string when necessary

print("--- %s seconds ---" % (time.time() - start_time))
# Out:
# Total count of teams:  1
# [[('Suspicious Tit For Tat', 'Stubborn Defect', 'Defector', 'Sucker Defect', 'Win-Shift Lose-Stay', 'Fourteen Defect', 'Two Defect', 'Bitter Cooperator')]]
# Instantiate PD Experiments with different game types
# Running experiments and computing data
# partition list:  [('Suspicious Tit For Tat', 'Stubborn Defect', 'Defector', 'Sucker Defect', 'Win-Shift Lose-Stay', 'Fourteen Defect', 'Two Defect', 'Bitter Cooperator')]
# Instantiating tournament object with these players:  Generic Memory One Player,Generic Memory One Player,Generic Memory One Player,Generic Memory One Player,Generic Memory One Player,Generic Memory One Player,Generic Memory One Player,Generic Memory One Player
# Playing matches: 100%|██████████| 36/36 [00:00<00:00, 1101.47it/s]
# Analysing: 100%|██████████| 25/25 [00:00<00:00, 50.80it/s]
#
# Match length for each user against other users:  [[[3.0, 4.0, 8.0, 21.0, 12.0, 20.0, 30.0, 2.0], [4.0, 4.0, 6.0, 2.0, 10.0, 16.0, 3.0, 6.0], [8.0, 6.0, 2.0, 12.0, 14.0, 21.0, 8.0, 6.0], [21.0, 2.0, 12.0, 4.0, 22.0, 12.0, 9.0, 17.0], [12.0, 10.0, 14.0, 22.0, 4.0, 3.0, 4.0, 1.0], [20.0, 16.0, 21.0, 12.0, 3.0, 3.0, 8.0, 21.0], [30.0, 3.0, 8.0, 9.0, 4.0, 8.0, 6.0, 1.0], [2.0, 6.0, 6.0, 17.0, 1.0, 21.0, 1.0, 2.0]]]
# Counting the number of CC states:
# player  1 states:
# {}
# {(D, D): 4}
# {(D, D): 8}
# {(D, D): 21}
# {(D, D): 12}
# {(D, D): 20}
# {(D, D): 30}
# {(C, D): 1, (D, C): 1}
# player  2 states:
# {(D, D): 4}
# {}
# {(D, D): 6}
# {(D, D): 2}
# {(D, D): 10}
# {(D, D): 16}
# {(D, D): 3}
# {(D, C): 3, (D, D): 3}
# player  3 states:
# {(D, D): 8}
# {(D, D): 6}
# {}
# {(D, D): 12}
# {(D, D): 14}
# {(D, D): 21}
# {(D, D): 8}
# {(D, C): 3, (D, D): 3}
# player  4 states:
# {(D, D): 21}
# {(D, D): 2}
# {(D, D): 12}
# {}
# {(D, D): 22}
# {(D, D): 12}
# {(D, D): 9}
# {(D, C): 9, (D, D): 8}
# player  5 states:
# {(D, D): 12}
# {(D, D): 10}
# {(D, D): 14}
# {(D, D): 22}
# {}
# {(D, D): 3}
# {(D, D): 4}
# {(D, C): 1}
# player  6 states:
# {(D, D): 20}
# {(D, D): 16}
# {(D, D): 21}
# {(D, D): 12}
# {(D, D): 3}
# {}
# {(D, D): 8}
# {(C, C): 19, (C, D): 1, (D, C): 1}
# player  7 states:
# {(D, D): 30}
# {(D, D): 3}
# {(D, D): 8}
# {(D, D): 9}
# {(D, D): 4}
# {(D, D): 8}
# {}
# {(D, C): 1}
# player  8 states:
# {(C, D): 1, (D, C): 1}
# {(C, D): 3, (D, D): 3}
# {(C, D): 3, (D, D): 3}
# {(C, D): 9, (D, D): 8}
# {(C, D): 1}
# {(C, C): 19, (C, D): 1, (D, C): 1}
# {(C, D): 1}
# {}
# The total number of CCs:  38
# str_list [('Suspicious Tit For Tat', 'Stubborn Defect', 'Defector', 'Sucker Defect', 'Win-Shift Lose-Stay', 'Fourteen Defect', 'Two Defect', 'Bitter Cooperator')]
# team list: [('Suspicious Tit For Tat', 'Stubborn Defect', 'Defector', 'Sucker Defect', 'Win-Shift Lose-Stay', 'Fourteen Defect', 'Two Defect', 'Bitter Cooperator')]
# str str: 11,10,8,12,14,9,13,1
# ***Processing number  1
# Save the data
# I am saving the data
# The file name is:  Data/Experiment2/ClassicPD_7D_Bitter_Cooperator_RPST_3_1_0_5.csv
# --- 0.7192623615264893 seconds ---

# %% [markdown]
# ### 7D + Bitter Cooperator results

# %%
# Let's compare the results
# Retrieve the stored data
classic_dataf = pd.read_csv('Data/Experiment2/ClassicPD_7D_Bitter_Cooperator_RPST_3_1_0_5.csv', index_col=0)

# Reset the index to accurately count the total systems
classic_dataf = classic_dataf.reset_index(drop=True)

# %%
classic_dataf.loc[:,:'SYS New CC Dist MIN']
# Out:
#               System ID  SYS MIN Score  SYS AVG Score  MIN of Team Avgs  \
# 0  11,10,8,12,14,9,13,1       0.988996       1.312375          1.312375
#
#    AVG of Team Mins  SYS CC Dist AVG  SYS CC Dist MIN  SYS New CC Dist AVG  \
# 0          0.988996         0.032313         0.032313             0.063545
#
#    SYS New CC Dist MIN
# 0             0.063545

# %%
with pd.option_context('display.max_rows', None, 'display.max_columns', None, 'display.max_colwidth', None):  # more options can be specified also
    display(classic_dataf[['System ID', 'Team1', 'Team1 Avg Score', 'Team1 New Avg Score', 
       'Team1 Min Score', 'Team1 Avg CC Dist', 'Team1 New Avg CC Dist']])
# Out:
#               System ID  \
# 0  11,10,8,12,14,9,13,1
#
#                                                                                                                                                                                                              Team1  \
# 0  Generic Memory One Player,Generic Memory One Player,Generic Memory One Player,Generic Memory One Player,Generic Memory One Player,Generic Memory One Player,Generic Memory One Player,Generic Memory One Player
#
#    Team1 Avg Score  Team1 New Avg Score  Team1 Min Score  Team1 Avg CC Dist  \
# 0         1.312375             2.464883         0.988996           0.032313
#
#    Team1 New Avg CC Dist
# 0               0.063545

# %% [markdown]
# ### 7D + Cooperator (1, 1, 1, 1)

# %%
import axelrod as axl
from axelrod.action import Action

players = ['Defector', 'Fourteen Defect', 'Stubborn Defect', 'Suspicious Tit For Tat', 'Sucker Defect', 'Two Defect', 'Win-Shift Lose-Stay',                'Cooperator']
part_list = list(partitions(players,8))

p = Path('7_defect_Cooperator.txt')
p.touch()
with open(p, "w") as f:
    json.dump(part_list, f)

# %%
print('Total count of teams: ',len(part_list))
print(part_list)
start_time = time.time()

print('Instantiate PD Experiments with different game types')
classic_pdExp = pd_exp.PdExp(part_list)

print('Running experiments and computing data')
classic_pdExp.run_experiments()

print('Save the data')
path = 'Data/Experiment2/'
classic_pdExp.save_data(path, 'ClassicPD_7D_Cooperator')  # CHANGE file_name string when necessary

print("--- %s seconds ---" % (time.time() - start_time))
# Out:
# Total count of teams:  1
# [[('Suspicious Tit For Tat', 'Stubborn Defect', 'Defector', 'Cooperator', 'Win-Shift Lose-Stay', 'Fourteen Defect', 'Two Defect', 'Sucker Defect')]]
# Instantiate PD Experiments with different game types
# Running experiments and computing data
# partition list:  [('Suspicious Tit For Tat', 'Stubborn Defect', 'Defector', 'Cooperator', 'Win-Shift Lose-Stay', 'Fourteen Defect', 'Two Defect', 'Sucker Defect')]
# Instantiating tournament object with these players:  Generic Memory One Player,Generic Memory One Player,Generic Memory One Player,Generic Memory One Player,Generic Memory One Player,Generic Memory One Player,Generic Memory One Player,Generic Memory One Player
# Playing matches: 100%|██████████| 36/36 [00:00<00:00, 2238.92it/s]
# Analysing: 100%|██████████| 25/25 [00:00<00:00, 50.60it/s]
#
# Match length for each user against other users:  [[[3.0, 4.0, 8.0, 21.0, 12.0, 20.0, 30.0, 2.0], [4.0, 4.0, 6.0, 2.0, 10.0, 16.0, 3.0, 6.0], [8.0, 6.0, 2.0, 12.0, 14.0, 21.0, 8.0, 6.0], [21.0, 2.0, 12.0, 4.0, 22.0, 12.0, 9.0, 17.0], [12.0, 10.0, 14.0, 22.0, 4.0, 3.0, 4.0, 1.0], [20.0, 16.0, 21.0, 12.0, 3.0, 3.0, 8.0, 21.0], [30.0, 3.0, 8.0, 9.0, 4.0, 8.0, 6.0, 1.0], [2.0, 6.0, 6.0, 17.0, 1.0, 21.0, 1.0, 2.0]]]
# Counting the number of CC states:
# player  1 states:
# {}
# {(D, D): 4}
# {(D, D): 8}
# {(C, C): 20, (D, C): 1}
# {(D, D): 12}
# {(D, D): 20}
# {(D, D): 30}
# {(D, D): 2}
# player  2 states:
# {(D, D): 4}
# {}
# {(D, D): 6}
# {(D, C): 2}
# {(D, D): 10}
# {(D, D): 16}
# {(D, D): 3}
# {(D, D): 6}
# player  3 states:
# {(D, D): 8}
# {(D, D): 6}
# {}
# {(D, C): 12}
# {(D, D): 14}
# {(D, D): 21}
# {(D, D): 8}
# {(D, D): 6}
# player  4 states:
# {(C, C): 20, (C, D): 1}
# {(C, D): 2}
# {(C, D): 12}
# {}
# {(C, C): 11, (C, D): 11}
# {(C, C): 11, (C, D): 1}
# {(C, C): 4, (C, D): 5}
# {(C, D): 17}
# player  5 states:
# {(D, D): 12}
# {(D, D): 10}
# {(D, D): 14}
# {(C, C): 11, (D, C): 11}
# {}
# {(D, D): 3}
# {(D, D): 4}
# {(D, D): 1}
# player  6 states:
# {(D, D): 20}
# {(D, D): 16}
# {(D, D): 21}
# {(C, C): 11, (D, C): 1}
# {(D, D): 3}
# {}
# {(D, D): 8}
# {(D, D): 21}
# player  7 states:
# {(D, D): 30}
# {(D, D): 3}
# {(D, D): 8}
# {(C, C): 4, (D, C): 5}
# {(D, D): 4}
# {(D, D): 8}
# {}
# {(D, D): 1}
# player  8 states:
# {(D, D): 2}
# {(D, D): 6}
# {(D, D): 6}
# {(D, C): 17}
# {(D, D): 1}
# {(D, D): 21}
# {(D, D): 1}
# {}
# The total number of CCs:  92
# str_list [('Suspicious Tit For Tat', 'Stubborn Defect', 'Defector', 'Cooperator', 'Win-Shift Lose-Stay', 'Fourteen Defect', 'Two Defect', 'Sucker Defect')]
# team list: [('Suspicious Tit For Tat', 'Stubborn Defect', 'Defector', 'Cooperator', 'Win-Shift Lose-Stay', 'Fourteen Defect', 'Two Defect', 'Sucker Defect')]
# str str: 11,10,8,2,14,9,13,12
# ***Processing number  1
# Save the data
# I am saving the data
# The file name is:  Data/Experiment2/ClassicPD_7D_Cooperator_RPST_3_1_0_5.csv
# --- 0.6925010681152344 seconds ---

# %% [markdown]
# ### 7D + Cooperator results

# %%
# Let's compare the results
# Retrieve the stored data
classic_dataf = pd.read_csv('Data/Experiment2/ClassicPD_7D_Cooperator_RPST_3_1_0_5.csv', index_col=0)

# Reset the index to accurately count the total systems
classic_dataf = classic_dataf.reset_index(drop=True)
classic_dataf.loc[:,:'SYS New CC Dist MIN']
# Out:
#               System ID  SYS MIN Score  SYS AVG Score  MIN of Team Avgs  \
# 0  11,10,8,2,14,9,13,12       1.205782       1.425241          1.425241
#
#    AVG of Team Mins  SYS CC Dist AVG  SYS CC Dist MIN  SYS New CC Dist AVG  \
# 0          1.205782         0.100482         0.100482             0.153846
#
#    SYS New CC Dist MIN
# 0             0.153846

# %%
with pd.option_context('display.max_rows', None, 'display.max_columns', None, 'display.max_colwidth', None):  # more options can be specified also
    display(classic_dataf[['System ID', 'Team1', 'Team1 Avg Score', 'Team1 New Avg Score', 
       'Team1 Min Score', 'Team1 Avg CC Dist', 'Team1 New Avg CC Dist']])
# Out:
#               System ID  \
# 0  11,10,8,2,14,9,13,12
#
#                                                                                                                                                                                                              Team1  \
# 0  Generic Memory One Player,Generic Memory One Player,Generic Memory One Player,Generic Memory One Player,Generic Memory One Player,Generic Memory One Player,Generic Memory One Player,Generic Memory One Player
#
#    Team1 Avg Score  Team1 New Avg Score  Team1 Min Score  Team1 Avg CC Dist  \
# 0         1.425241             3.107023         1.205782           0.100482
#
#    Team1 New Avg CC Dist
# 0               0.153846

# %% [markdown]
# ### 7C + Fourteen Coop (1, 1, 1, 0)

# %%
import axelrod as axl
players = ['Defector', 'Fourteen Defect', 'Stubborn Defect', 'Suspicious Tit For Tat', 'Sucker Defect', 'Two Defect', 'Win-Shift Lose-Stay',                'Fourteen Coop']
part_list = list(partitions(players,8))

p = Path('7_defect_Fourteen_Coop.txt')
p.touch()
with open(p, "w") as f:
    json.dump(part_list, f)

# %%
print('Total count of teams: ',len(part_list))
print(part_list)
start_time = time.time()

print('Instantiate PD Experiments with different game types')
classic_pdExp = pd_exp.PdExp(part_list)

print('Running experiments and computing data')
classic_pdExp.run_experiments()

print('Save the data')
path = 'Data/Experiment2/'
classic_pdExp.save_data(path, 'ClassicPD_7D_Fourteen_Coop')  # CHANGE file_name string when necessary

print("--- %s seconds ---" % (time.time() - start_time))
# Out:
# Total count of teams:  1
# [[('Suspicious Tit For Tat', 'Stubborn Defect', 'Fourteen Coop', 'Defector', 'Win-Shift Lose-Stay', 'Fourteen Defect', 'Two Defect', 'Sucker Defect')]]
# Instantiate PD Experiments with different game types
# Running experiments and computing data
# partition list:  [('Suspicious Tit For Tat', 'Stubborn Defect', 'Fourteen Coop', 'Defector', 'Win-Shift Lose-Stay', 'Fourteen Defect', 'Two Defect', 'Sucker Defect')]
# Instantiating tournament object with these players:  Generic Memory One Player,Generic Memory One Player,Generic Memory One Player,Generic Memory One Player,Generic Memory One Player,Generic Memory One Player,Generic Memory One Player,Generic Memory One Player
# Playing matches: 100%|██████████| 36/36 [00:00<00:00, 749.38it/s]
# Analysing: 100%|██████████| 25/25 [00:00<00:00, 52.17it/s]
#
# Match length for each user against other users:  [[[3.0, 4.0, 8.0, 21.0, 12.0, 20.0, 30.0, 2.0], [4.0, 4.0, 6.0, 2.0, 10.0, 16.0, 3.0, 6.0], [8.0, 6.0, 2.0, 12.0, 14.0, 21.0, 8.0, 6.0], [21.0, 2.0, 12.0, 4.0, 22.0, 12.0, 9.0, 17.0], [12.0, 10.0, 14.0, 22.0, 4.0, 3.0, 4.0, 1.0], [20.0, 16.0, 21.0, 12.0, 3.0, 3.0, 8.0, 21.0], [30.0, 3.0, 8.0, 9.0, 4.0, 8.0, 6.0, 1.0], [2.0, 6.0, 6.0, 17.0, 1.0, 21.0, 1.0, 2.0]]]
# Counting the number of CC states:
# player  1 states:
# {}
# {(D, D): 4}
# {(C, C): 7, (D, C): 1}
# {(D, D): 21}
# {(D, D): 12}
# {(D, D): 20}
# {(D, D): 30}
# {(D, D): 2}
# player  2 states:
# {(D, D): 4}
# {}
# {(D, C): 6}
# {(D, D): 2}
# {(D, D): 10}
# {(D, D): 16}
# {(D, D): 3}
# {(D, D): 6}
# player  3 states:
# {(C, C): 7, (C, D): 1}
# {(C, D): 6}
# {}
# {(C, D): 12}
# {(C, C): 7, (C, D): 7}
# {(C, C): 20, (C, D): 1}
# {(C, C): 4, (C, D): 4}
# {(C, D): 6}
# player  4 states:
# {(D, D): 21}
# {(D, D): 2}
# {(D, C): 12}
# {}
# {(D, D): 22}
# {(D, D): 12}
# {(D, D): 9}
# {(D, D): 17}
# player  5 states:
# {(D, D): 12}
# {(D, D): 10}
# {(C, C): 7, (D, C): 7}
# {(D, D): 22}
# {}
# {(D, D): 3}
# {(D, D): 4}
# {(D, D): 1}
# player  6 states:
# {(D, D): 20}
# {(D, D): 16}
# {(C, C): 20, (D, C): 1}
# {(D, D): 12}
# {(D, D): 3}
# {}
# {(D, D): 8}
# {(D, D): 21}
# player  7 states:
# {(D, D): 30}
# {(D, D): 3}
# {(C, C): 4, (D, C): 4}
# {(D, D): 9}
# {(D, D): 4}
# {(D, D): 8}
# {}
# {(D, D): 1}
# player  8 states:
# {(D, D): 2}
# {(D, D): 6}
# {(D, C): 6}
# {(D, D): 17}
# {(D, D): 1}
# {(D, D): 21}
# {(D, D): 1}
# {}
# The total number of CCs:  76
# str_list [('Suspicious Tit For Tat', 'Stubborn Defect', 'Fourteen Coop', 'Defector', 'Win-Shift Lose-Stay', 'Fourteen Defect', 'Two Defect', 'Sucker Defect')]
# team list: [('Suspicious Tit For Tat', 'Stubborn Defect', 'Fourteen Coop', 'Defector', 'Win-Shift Lose-Stay', 'Fourteen Defect', 'Two Defect', 'Sucker Defect')]
# str str: 11,10,3,8,14,9,13,12
# ***Processing number  1
# Save the data
# I am saving the data
# The file name is:  Data/Experiment2/ClassicPD_7D_Fourteen_Coop_RPST_3_1_0_5.csv
# --- 0.6556379795074463 seconds ---

# %% [markdown]
# ### 7C + Fourteen Coop results

# %%
classic_dataf = pd.read_csv('Data/Experiment2/ClassicPD_7D_Fourteen_Coop_RPST_3_1_0_5.csv', index_col=0)

classic_dataf = classic_dataf.reset_index(drop=True)
classic_dataf.loc[:,:'SYS New CC Dist MIN']
# Out:
#               System ID  SYS MIN Score  SYS AVG Score  MIN of Team Avgs  \
# 0  11,10,3,8,14,9,13,12       1.211735       1.425489          1.425489
#
#    AVG of Team Mins  SYS CC Dist AVG  SYS CC Dist MIN  SYS New CC Dist AVG  \
# 0          1.211735         0.100978         0.100978              0.12709
#
#    SYS New CC Dist MIN
# 0              0.12709

# %%
with pd.option_context('display.max_rows', None, 'display.max_columns', None, 'display.max_colwidth', None):  # more options can be specified also
    display(classic_dataf[['System ID', 'Team1', 'Team1 Avg Score', 'Team1 New Avg Score', 
       'Team1 Min Score', 'Team1 Avg CC Dist', 'Team1 New Avg CC Dist']])
# Out:
#               System ID  \
# 0  11,10,3,8,14,9,13,12
#
#                                                                                                                                                                                                              Team1  \
# 0  Generic Memory One Player,Generic Memory One Player,Generic Memory One Player,Generic Memory One Player,Generic Memory One Player,Generic Memory One Player,Generic Memory One Player,Generic Memory One Player
#
#    Team1 Avg Score  Team1 New Avg Score  Team1 Min Score  Team1 Avg CC Dist  \
# 0         1.425489             2.879599         1.211735           0.100978
#
#    Team1 New Avg CC Dist
# 0                0.12709

# %% [markdown]
# ### 7D + Grim Trigger (1, 0, 0, 0)

# %%
import axelrod as axl
players = ['Defector', 'Fourteen Defect', 'Stubborn Defect', 'Suspicious Tit For Tat', 'Sucker Defect', 'Two Defect', 'Win-Shift Lose-Stay',                'Grim Trigger']
part_list = list(partitions(players,8))

p = Path('7_defect_Grim_Trigger.txt')
p.touch()
with open(p, "w") as f:
    json.dump(part_list, f)

# %%
print('Total count of teams: ',len(part_list))
print(part_list)
start_time = time.time()

print('Instantiate PD Experiments with different game types')
classic_pdExp = pd_exp.PdExp(part_list)

print('Running experiments and computing data')
classic_pdExp.run_experiments()

print('Save the data')
path = 'Data/Experiment2/'
classic_pdExp.save_data(path, 'ClassicPD_7D_Grim_Trigger')  # CHANGE file_name string when necessary

print("--- %s seconds ---" % (time.time() - start_time))
# Out:
# Total count of teams:  1
# [[('Grim Trigger', 'Suspicious Tit For Tat', 'Stubborn Defect', 'Defector', 'Win-Shift Lose-Stay', 'Fourteen Defect', 'Two Defect', 'Sucker Defect')]]
# Instantiate PD Experiments with different game types
# Running experiments and computing data
# partition list:  [('Grim Trigger', 'Suspicious Tit For Tat', 'Stubborn Defect', 'Defector', 'Win-Shift Lose-Stay', 'Fourteen Defect', 'Two Defect', 'Sucker Defect')]
# Instantiating tournament object with these players:  Generic Memory One Player,Generic Memory One Player,Generic Memory One Player,Generic Memory One Player,Generic Memory One Player,Generic Memory One Player,Generic Memory One Player,Generic Memory One Player
# Playing matches: 100%|██████████| 36/36 [00:00<00:00, 1310.92it/s]
# Analysing: 100%|██████████| 25/25 [00:00<00:00, 50.16it/s]
# Match length for each user against other users:  [[[3.0, 4.0, 8.0, 21.0, 12.0, 20.0, 30.0, 2.0], [4.0, 4.0, 6.0, 2.0, 10.0, 16.0, 3.0, 6.0], [8.0, 6.0, 2.0, 12.0, 14.0, 21.0, 8.0, 6.0], [21.0, 2.0, 12.0, 4.0, 22.0, 12.0, 9.0, 17.0], [12.0, 10.0, 14.0, 22.0, 4.0, 3.0, 4.0, 1.0], [20.0, 16.0, 21.0, 12.0, 3.0, 3.0, 8.0, 21.0], [30.0, 3.0, 8.0, 9.0, 4.0, 8.0, 6.0, 1.0], [2.0, 6.0, 6.0, 17.0, 1.0, 21.0, 1.0, 2.0]]]
# Counting the number of CC states:
# player  1 states:
# {}
# {(C, D): 1, (D, C): 1, (D, D): 2}
# {(C, D): 1, (D, D): 7}
# {(C, D): 1, (D, D): 20}
# {(C, D): 1, (D, C): 11}
# {(C, D): 1, (D, C): 19}
# {(C, D): 1, (D, C): 1, (D, D): 28}
# {(C, D): 1, (D, D): 1}
# player  2 states:
# {(C, D): 1, (D, C): 1, (D, D): 2}
# {}
# {(D, D): 6}
# {(D, D): 2}
# {(D, D): 10}
# {(D, D): 16}
# {(D, D): 3}
# {(D, D): 6}
# player  3 states:
# {(D, C): 1, (D, D): 7}
# {(D, D): 6}
# {}
# {(D, D): 12}
# {(D, D): 14}
# {(D, D): 21}
# {(D, D): 8}
# {(D, D): 6}
# player  4 states:
# {(D, C): 1, (D, D): 20}
# {(D, D): 2}
# {(D, D): 12}
# {}
# {(D, D): 22}
# {(D, D): 12}
# {(D, D): 9}
# {(D, D): 17}
# player  5 states:
# {(C, D): 11, (D, C): 1}
# {(D, D): 10}
# {(D, D): 14}
# {(D, D): 22}
# {}
# {(D, D): 3}
# {(D, D): 4}
# {(D, D): 1}
# player  6 states:
# {(C, D): 19, (D, C): 1}
# {(D, D): 16}
# {(D, D): 21}
# {(D, D): 12}
# {(D, D): 3}
# {}
# {(D, D): 8}
# {(D, D): 21}
# player  7 states:
# {(C, D): 1, (D, C): 1, (D, D): 28}
# {(D, D): 3}
# {(D, D): 8}
# {(D, D): 9}
# {(D, D): 4}
# {(D, D): 8}
# {}
# {(D, D): 1}
# player  8 states:
# {(D, C): 1, (D, D): 1}
# {(D, D): 6}
# {(D, D): 6}
# {(D, D): 17}
# {(D, D): 1}
# {(D, D): 21}
# {(D, D): 1}
# {}
# The total number of CCs:  0
# str_list [('Grim Trigger', 'Suspicious Tit For Tat', 'Stubborn Defect', 'Defector', 'Win-Shift Lose-Stay', 'Fourteen Defect', 'Two Defect', 'Sucker Defect')]
# team list: [('Grim Trigger', 'Suspicious Tit For Tat', 'Stubborn Defect', 'Defector', 'Win-Shift Lose-Stay', 'Fourteen Defect', 'Two Defect', 'Sucker Defect')]
# str str: 4,11,10,8,14,9,13,12
# ***Processing number  1
# Save the data
# I am saving the data
# The file name is:  Data/Experiment2/ClassicPD_7D_Grim_Trigger_RPST_3_1_0_5.csv
# --- 0.6822071075439453 seconds ---

# %% [markdown]
# ### 7D + Grim Trigger results

# %%
classic_dataf = pd.read_csv('Data/Experiment2/ClassicPD_7D_Grim_Trigger_RPST_3_1_0_5.csv', index_col=0)

classic_dataf = classic_dataf.reset_index(drop=True)
classic_dataf.loc[:,:'SYS New CC Dist MIN']
# Out:
#               System ID  SYS MIN Score  SYS AVG Score  MIN of Team Avgs  \
# 0  4,11,10,8,14,9,13,12       0.892857       1.173533          1.173533
#
#    AVG of Team Mins  SYS CC Dist AVG  SYS CC Dist MIN  SYS New CC Dist AVG  \
# 0          0.892857              0.0              0.0                  0.0
#
#    SYS New CC Dist MIN
# 0                  0.0

# %%
with pd.option_context('display.max_rows', None, 'display.max_columns', None, 'display.max_colwidth', None):  # more options can be specified also
    display(classic_dataf[['System ID', 'Team1', 'Team1 Avg Score', 'Team1 New Avg Score', 
       'Team1 Min Score', 'Team1 Avg CC Dist', 'Team1 New Avg CC Dist']])
# Out:
#               System ID  \
# 0  4,11,10,8,14,9,13,12
#
#                                                                                                                                                                                                              Team1  \
# 0  Generic Memory One Player,Generic Memory One Player,Generic Memory One Player,Generic Memory One Player,Generic Memory One Player,Generic Memory One Player,Generic Memory One Player,Generic Memory One Player
#
#    Team1 Avg Score  Team1 New Avg Score  Team1 Min Score  Team1 Avg CC Dist  \
# 0         1.173533             2.391304         0.892857                0.0
#
#    Team1 New Avg CC Dist
# 0                    0.0

# %% [markdown]
# ### 7D + Thirteen Coop (1, 1, 0, 1))

# %%
import axelrod as axl
players = ['Defector', 'Fourteen Defect', 'Stubborn Defect', 'Suspicious Tit For Tat', 'Sucker Defect', 'Two Defect', 'Win-Shift Lose-Stay',                'Thirteen Coop']
part_list = list(partitions(players,8))

p = Path('7_defect_Thirteen_Coop.txt')
p.touch()
with open(p, "w") as f:
    json.dump(part_list, f)

# %%
print('Total count of teams: ',len(part_list))
print(part_list)
start_time = time.time()

print('Instantiate PD Experiments with different game types')
classic_pdExp = pd_exp.PdExp(part_list)

print('Running experiments and computing data')
classic_pdExp.run_experiments()

print('Save the data')
path = 'Data/Experiment2/'
classic_pdExp.save_data(path, 'ClassicPD_7D_Thirteen_Coop')  # CHANGE file_name string when necessary

print("--- %s seconds ---" % (time.time() - start_time))
# Out:
# Total count of teams:  1
# [[('Defector', 'Stubborn Defect', 'Suspicious Tit For Tat', 'Thirteen Coop', 'Win-Shift Lose-Stay', 'Fourteen Defect', 'Two Defect', 'Sucker Defect')]]
# Instantiate PD Experiments with different game types
# Running experiments and computing data
# partition list:  [('Defector', 'Stubborn Defect', 'Suspicious Tit For Tat', 'Thirteen Coop', 'Win-Shift Lose-Stay', 'Fourteen Defect', 'Two Defect', 'Sucker Defect')]
# Instantiating tournament object with these players:  Generic Memory One Player,Generic Memory One Player,Generic Memory One Player,Generic Memory One Player,Generic Memory One Player,Generic Memory One Player,Generic Memory One Player,Generic Memory One Player
# Playing matches: 100%|██████████| 36/36 [00:00<00:00, 709.75it/s]
# Analysing: 100%|██████████| 25/25 [00:00<00:00, 42.35it/s]
# Match length for each user against other users:  [[[3.0, 4.0, 8.0, 21.0, 12.0, 20.0, 30.0, 2.0], [4.0, 4.0, 6.0, 2.0, 10.0, 16.0, 3.0, 6.0], [8.0, 6.0, 2.0, 12.0, 14.0, 21.0, 8.0, 6.0], [21.0, 2.0, 12.0, 4.0, 22.0, 12.0, 9.0, 17.0], [12.0, 10.0, 14.0, 22.0, 4.0, 3.0, 4.0, 1.0], [20.0, 16.0, 21.0, 12.0, 3.0, 3.0, 8.0, 21.0], [30.0, 3.0, 8.0, 9.0, 4.0, 8.0, 6.0, 1.0], [2.0, 6.0, 6.0, 17.0, 1.0, 21.0, 1.0, 2.0]]]
# Counting the number of CC states:
# player  1 states:
# {}
# {(D, D): 4}
# {(D, D): 8}
# {(D, C): 21}
# {(D, D): 12}
# {(D, D): 20}
# {(D, D): 30}
# {(D, D): 2}
# player  2 states:
# {(D, D): 4}
# {}
# {(D, D): 6}
# {(D, C): 2}
# {(D, D): 10}
# {(D, D): 16}
# {(D, D): 3}
# {(D, D): 6}
# player  3 states:
# {(D, D): 8}
# {(D, D): 6}
# {}
# {(C, C): 11, (D, C): 1}
# {(D, D): 14}
# {(D, D): 21}
# {(D, D): 8}
# {(D, D): 6}
# player  4 states:
# {(C, D): 21}
# {(C, D): 2}
# {(C, C): 11, (C, D): 1}
# {}
# {(C, C): 11, (C, D): 11}
# {(C, C): 11, (C, D): 1}
# {(C, C): 4, (C, D): 5}
# {(C, D): 17}
# player  5 states:
# {(D, D): 12}
# {(D, D): 10}
# {(D, D): 14}
# {(C, C): 11, (D, C): 11}
# {}
# {(D, D): 3}
# {(D, D): 4}
# {(D, D): 1}
# player  6 states:
# {(D, D): 20}
# {(D, D): 16}
# {(D, D): 21}
# {(C, C): 11, (D, C): 1}
# {(D, D): 3}
# {}
# {(D, D): 8}
# {(D, D): 21}
# player  7 states:
# {(D, D): 30}
# {(D, D): 3}
# {(D, D): 8}
# {(C, C): 4, (D, C): 5}
# {(D, D): 4}
# {(D, D): 8}
# {}
# {(D, D): 1}
# player  8 states:
# {(D, D): 2}
# {(D, D): 6}
# {(D, D): 6}
# {(D, C): 17}
# {(D, D): 1}
# {(D, D): 21}
# {(D, D): 1}
# {}
# The total number of CCs:  74
# str_list [('Defector', 'Stubborn Defect', 'Suspicious Tit For Tat', 'Thirteen Coop', 'Win-Shift Lose-Stay', 'Fourteen Defect', 'Two Defect', 'Sucker Defect')]
# team list: [('Defector', 'Stubborn Defect', 'Suspicious Tit For Tat', 'Thirteen Coop', 'Win-Shift Lose-Stay', 'Fourteen Defect', 'Two Defect', 'Sucker Defect')]
# str str: 8,10,11,5,14,9,13,12
# ***Processing number  1
# Save the data
# I am saving the data
# The file name is:  Data/Experiment2/ClassicPD_7D_Thirteen_Coop_RPST_3_1_0_5.csv
# --- 0.7785143852233887 seconds ---

# %% [markdown]
# ### 7D + Thirteen Coop results

# %%
classic_dataf = pd.read_csv('Data/Experiment2/ClassicPD_7D_Thirteen_Coop_RPST_3_1_0_5.csv', index_col=0)

classic_dataf = classic_dataf.reset_index(drop=True)
classic_dataf.loc[:,:'SYS New CC Dist MIN']
# Out:
#               System ID  SYS MIN Score  SYS AVG Score  MIN of Team Avgs  \
# 0  8,10,11,5,14,9,13,12       1.190476       1.424603          1.424603
#
#    AVG of Team Mins  SYS CC Dist AVG  SYS CC Dist MIN  SYS New CC Dist AVG  \
# 0          1.190476         0.099206         0.099206             0.123746
#
#    SYS New CC Dist MIN
# 0             0.123746

# %%
with pd.option_context('display.max_rows', None, 'display.max_columns', None, 'display.max_colwidth', None):  # more options can be specified also
    display(classic_dataf[['System ID', 'Team1', 'Team1 Avg Score', 'Team1 New Avg Score', 
       'Team1 Min Score', 'Team1 Avg CC Dist', 'Team1 New Avg CC Dist']])
# Out:
#               System ID  \
# 0  8,10,11,5,14,9,13,12
#
#                                                                                                                                                                                                              Team1  \
# 0  Generic Memory One Player,Generic Memory One Player,Generic Memory One Player,Generic Memory One Player,Generic Memory One Player,Generic Memory One Player,Generic Memory One Player,Generic Memory One Player
#
#    Team1 Avg Score  Team1 New Avg Score  Team1 Min Score  Team1 Avg CC Dist  \
# 0         1.424603             3.076923         1.190476           0.099206
#
#    Team1 New Avg CC Dist
# 0               0.123746

# %% [markdown]
# ### 7D + Tit For Tat (1, 0, 1, 0)

# %%
import axelrod as axl
players = ['Defector', 'Fourteen Defect', 'Stubborn Defect', 'Suspicious Tit For Tat', 'Sucker Defect', 'Two Defect', 'Win-Shift Lose-Stay',                'Tit For Tat']
part_list = list(partitions(players,8))

p = Path('7_defect_Tit_for_Tat.txt')
p.touch()
with open(p, "w") as f:
    json.dump(part_list, f)

# %%
print('Total count of teams: ',len(part_list))
print(part_list)
start_time = time.time()

print('Instantiate PD Experiments with different game types')
classic_pdExp = pd_exp.PdExp(part_list)

print('Running experiments and computing data')
classic_pdExp.run_experiments()

print('Save the data')
path = 'Data/Experiment2/'
classic_pdExp.save_data(path, 'ClassicPD_7D_Tit_for_Tat')  # CHANGE file_name string when necessary

print("--- %s seconds ---" % (time.time() - start_time))
# Out:
# Total count of teams:  1
# [[('Defector', 'Stubborn Defect', 'Tit For Tat', 'Suspicious Tit For Tat', 'Win-Shift Lose-Stay', 'Fourteen Defect', 'Two Defect', 'Sucker Defect')]]
# Instantiate PD Experiments with different game types
# Running experiments and computing data
# partition list:  [('Defector', 'Stubborn Defect', 'Tit For Tat', 'Suspicious Tit For Tat', 'Win-Shift Lose-Stay', 'Fourteen Defect', 'Two Defect', 'Sucker Defect')]
# Instantiating tournament object with these players:  Generic Memory One Player,Generic Memory One Player,Generic Memory One Player,Generic Memory One Player,Generic Memory One Player,Generic Memory One Player,Generic Memory One Player,Generic Memory One Player
# Playing matches: 100%|██████████| 36/36 [00:00<00:00, 715.97it/s]
# Analysing: 100%|██████████| 25/25 [00:00<00:00, 44.88it/s]
#
# Match length for each user against other users:  [[[3.0, 4.0, 8.0, 21.0, 12.0, 20.0, 30.0, 2.0], [4.0, 4.0, 6.0, 2.0, 10.0, 16.0, 3.0, 6.0], [8.0, 6.0, 2.0, 12.0, 14.0, 21.0, 8.0, 6.0], [21.0, 2.0, 12.0, 4.0, 22.0, 12.0, 9.0, 17.0], [12.0, 10.0, 14.0, 22.0, 4.0, 3.0, 4.0, 1.0], [20.0, 16.0, 21.0, 12.0, 3.0, 3.0, 8.0, 21.0], [30.0, 3.0, 8.0, 9.0, 4.0, 8.0, 6.0, 1.0], [2.0, 6.0, 6.0, 17.0, 1.0, 21.0, 1.0, 2.0]]]
# Counting the number of CC states:
# player  1 states:
# {}
# {(D, D): 4}
# {(D, C): 1, (D, D): 7}
# {(D, D): 21}
# {(D, D): 12}
# {(D, D): 20}
# {(D, D): 30}
# {(D, D): 2}
# player  2 states:
# {(D, D): 4}
# {}
# {(D, C): 1, (D, D): 5}
# {(D, D): 2}
# {(D, D): 10}
# {(D, D): 16}
# {(D, D): 3}
# {(D, D): 6}
# player  3 states:
# {(C, D): 1, (D, D): 7}
# {(C, D): 1, (D, D): 5}
# {}
# {(C, D): 6, (D, C): 6}
# {(C, C): 4, (C, D): 5, (D, C): 5}
# {(C, C): 19, (C, D): 1, (D, C): 1}
# {(C, D): 4, (D, C): 4}
# {(C, D): 1, (D, D): 5}
# player  4 states:
# {(D, D): 21}
# {(D, D): 2}
# {(C, D): 6, (D, C): 6}
# {}
# {(D, D): 22}
# {(D, D): 12}
# {(D, D): 9}
# {(D, D): 17}
# player  5 states:
# {(D, D): 12}
# {(D, D): 10}
# {(C, C): 4, (C, D): 5, (D, C): 5}
# {(D, D): 22}
# {}
# {(D, D): 3}
# {(D, D): 4}
# {(D, D): 1}
# player  6 states:
# {(D, D): 20}
# {(D, D): 16}
# {(C, C): 19, (C, D): 1, (D, C): 1}
# {(D, D): 12}
# {(D, D): 3}
# {}
# {(D, D): 8}
# {(D, D): 21}
# player  7 states:
# {(D, D): 30}
# {(D, D): 3}
# {(C, D): 4, (D, C): 4}
# {(D, D): 9}
# {(D, D): 4}
# {(D, D): 8}
# {}
# {(D, D): 1}
# player  8 states:
# {(D, D): 2}
# {(D, D): 6}
# {(D, C): 1, (D, D): 5}
# {(D, D): 17}
# {(D, D): 1}
# {(D, D): 21}
# {(D, D): 1}
# {}
# The total number of CCs:  46
# str_list [('Defector', 'Stubborn Defect', 'Tit For Tat', 'Suspicious Tit For Tat', 'Win-Shift Lose-Stay', 'Fourteen Defect', 'Two Defect', 'Sucker Defect')]
# team list: [('Defector', 'Stubborn Defect', 'Tit For Tat', 'Suspicious Tit For Tat', 'Win-Shift Lose-Stay', 'Fourteen Defect', 'Two Defect', 'Sucker Defect')]
# str str: 8,10,6,11,14,9,13,12
# ***Processing number  1
# Save the data
# I am saving the data
# The file name is:  Data/Experiment2/ClassicPD_7D_Tit_for_Tat_RPST_3_1_0_5.csv
# --- 0.7545545101165771 seconds ---

# %% [markdown]
# ### 7D + Tit For Tat results

# %%
classic_dataf = pd.read_csv('Data/Experiment2/ClassicPD_7D_Tit_for_Tat_RPST_3_1_0_5.csv', index_col=0)

classic_dataf = classic_dataf.reset_index(drop=True)
classic_dataf.loc[:,:'SYS New CC Dist MIN']
# Out:
#               System ID  SYS MIN Score  SYS AVG Score  MIN of Team Avgs  \
# 0  8,10,6,11,14,9,13,12       1.071429       1.260098          1.260098
#
#    AVG of Team Mins  SYS CC Dist AVG  SYS CC Dist MIN  SYS New CC Dist AVG  \
# 0          1.071429         0.042517         0.042517             0.076923
#
#    SYS New CC Dist MIN
# 0             0.076923

# %%
with pd.option_context('display.max_rows', None, 'display.max_columns', None, 'display.max_colwidth', None):  # more options can be specified also
    display(classic_dataf[['System ID', 'Team1', 'Team1 Avg Score', 'Team1 New Avg Score', 
       'Team1 Min Score', 'Team1 Avg CC Dist', 'Team1 New Avg CC Dist']])
# Out:
#               System ID  \
# 0  8,10,6,11,14,9,13,12
#
#                                                                                                                                                                                                              Team1  \
# 0  Generic Memory One Player,Generic Memory One Player,Generic Memory One Player,Generic Memory One Player,Generic Memory One Player,Generic Memory One Player,Generic Memory One Player,Generic Memory One Player
#
#    Team1 Avg Score  Team1 New Avg Score  Team1 Min Score  Team1 Avg CC Dist  \
# 0         1.260098             2.658863         1.071429           0.042517
#
#    Team1 New Avg CC Dist
# 0               0.076923

# %% [markdown]
# ### 7D + Win-Stay Lose-Shift (1, 0, 0, 1)

# %%
import axelrod as axl
players = ['Defector', 'Fourteen Defect', 'Stubborn Defect', 'Suspicious Tit For Tat', 'Sucker Defect', 'Two Defect', 'Win-Shift Lose-Stay',                'Win-Stay Lose-Shift']
part_list = list(partitions(players,8))

p = Path('7_defect_Win-Stay_Lose-Shift.txt')
p.touch()
with open(p, "w") as f:
    json.dump(part_list, f)

# %%
print('Total count of teams: ',len(part_list))
print(part_list)
start_time = time.time()

print('Instantiate PD Experiments with different game types')
classic_pdExp = pd_exp.PdExp(part_list)

print('Running experiments and computing data')
classic_pdExp.run_experiments()

print('Save the data')
path = 'Data/Experiment2/'
classic_pdExp.save_data(path, 'ClassicPD_7D_Win-Stay_Lose-Shift')  # CHANGE file_name string when necessary

print("--- %s seconds ---" % (time.time() - start_time))
# Out:
# Total count of teams:  1
# [[('Suspicious Tit For Tat', 'Stubborn Defect', 'Defector', 'Win-Shift Lose-Stay', 'Fourteen Defect', 'Win-Stay Lose-Shift', 'Two Defect', 'Sucker Defect')]]
# Instantiate PD Experiments with different game types
# Running experiments and computing data
# partition list:  [('Suspicious Tit For Tat', 'Stubborn Defect', 'Defector', 'Win-Shift Lose-Stay', 'Fourteen Defect', 'Win-Stay Lose-Shift', 'Two Defect', 'Sucker Defect')]
# Instantiating tournament object with these players:  Generic Memory One Player,Generic Memory One Player,Generic Memory One Player,Generic Memory One Player,Generic Memory One Player,Generic Memory One Player,Generic Memory One Player,Generic Memory One Player
# Playing matches: 100%|██████████| 36/36 [00:00<00:00, 690.16it/s]
# Analysing: 100%|██████████| 25/25 [00:00<00:00, 42.17it/s]
#
# Match length for each user against other users:  [[[3.0, 4.0, 8.0, 21.0, 12.0, 20.0, 30.0, 2.0], [4.0, 4.0, 6.0, 2.0, 10.0, 16.0, 3.0, 6.0], [8.0, 6.0, 2.0, 12.0, 14.0, 21.0, 8.0, 6.0], [21.0, 2.0, 12.0, 4.0, 22.0, 12.0, 9.0, 17.0], [12.0, 10.0, 14.0, 22.0, 4.0, 3.0, 4.0, 1.0], [20.0, 16.0, 21.0, 12.0, 3.0, 3.0, 8.0, 21.0], [30.0, 3.0, 8.0, 9.0, 4.0, 8.0, 6.0, 1.0], [2.0, 6.0, 6.0, 17.0, 1.0, 21.0, 1.0, 2.0]]]
# Counting the number of CC states:
# player  1 states:
# {}
# {(D, D): 4}
# {(D, D): 8}
# {(D, D): 21}
# {(D, D): 12}
# {(C, D): 7, (D, C): 7, (D, D): 6}
# {(D, D): 30}
# {(D, D): 2}
# player  2 states:
# {(D, D): 4}
# {}
# {(D, D): 6}
# {(D, D): 2}
# {(D, D): 10}
# {(D, C): 8, (D, D): 8}
# {(D, D): 3}
# {(D, D): 6}
# player  3 states:
# {(D, D): 8}
# {(D, D): 6}
# {}
# {(D, D): 12}
# {(D, D): 14}
# {(D, C): 11, (D, D): 10}
# {(D, D): 8}
# {(D, D): 6}
# player  4 states:
# {(D, D): 21}
# {(D, D): 2}
# {(D, D): 12}
# {}
# {(D, D): 22}
# {(C, D): 11, (D, C): 1}
# {(D, D): 9}
# {(D, D): 17}
# player  5 states:
# {(D, D): 12}
# {(D, D): 10}
# {(D, D): 14}
# {(D, D): 22}
# {}
# {(C, D): 2, (D, C): 1}
# {(D, D): 4}
# {(D, D): 1}
# player  6 states:
# {(C, D): 7, (D, C): 7, (D, D): 6}
# {(C, D): 8, (D, D): 8}
# {(C, D): 11, (D, D): 10}
# {(C, D): 1, (D, C): 11}
# {(C, D): 1, (D, C): 2}
# {}
# {(C, D): 3, (D, C): 3, (D, D): 2}
# {(C, D): 11, (D, D): 10}
# player  7 states:
# {(D, D): 30}
# {(D, D): 3}
# {(D, D): 8}
# {(D, D): 9}
# {(D, D): 4}
# {(C, D): 3, (D, C): 3, (D, D): 2}
# {}
# {(D, D): 1}
# player  8 states:
# {(D, D): 2}
# {(D, D): 6}
# {(D, D): 6}
# {(D, D): 17}
# {(D, D): 1}
# {(D, C): 11, (D, D): 10}
# {(D, D): 1}
# {}
# The total number of CCs:  0
# str_list [('Suspicious Tit For Tat', 'Stubborn Defect', 'Defector', 'Win-Shift Lose-Stay', 'Fourteen Defect', 'Win-Stay Lose-Shift', 'Two Defect', 'Sucker Defect')]
# team list: [('Suspicious Tit For Tat', 'Stubborn Defect', 'Defector', 'Win-Shift Lose-Stay', 'Fourteen Defect', 'Win-Stay Lose-Shift', 'Two Defect', 'Sucker Defect')]
# str str: 11,10,8,14,9,7,13,12
# ***Processing number  1
# Save the data
# I am saving the data
# The file name is:  Data/Experiment2/ClassicPD_7D_Win-Stay_Lose-Shift_RPST_3_1_0_5.csv
# --- 0.7934699058532715 seconds ---

# %% [markdown]
# ### 7D + Win-Stay Lose-Shift results

# %%
classic_dataf = pd.read_csv('Data/Experiment2/ClassicPD_7D_Win-Stay_Lose-Shift_RPST_3_1_0_5.csv', index_col=0)

classic_dataf = classic_dataf.reset_index(drop=True)
classic_dataf.loc[:,:'SYS New CC Dist MIN']
# Out:
#               System ID  SYS MIN Score  SYS AVG Score  MIN of Team Avgs  \
# 0  11,10,8,14,9,7,13,12       0.916667        1.26773           1.26773
#
#    AVG of Team Mins  SYS CC Dist AVG  SYS CC Dist MIN  SYS New CC Dist AVG  \
# 0          0.916667              0.0              0.0                  0.0
#
#    SYS New CC Dist MIN
# 0                  0.0

# %%
with pd.option_context('display.max_rows', None, 'display.max_columns', None, 'display.max_colwidth', None):  # more options can be specified also
    display(classic_dataf[['System ID', 'Team1', 'Team1 Avg Score', 'Team1 New Avg Score', 
       'Team1 Min Score', 'Team1 Avg CC Dist', 'Team1 New Avg CC Dist']])
# Out:
#               System ID  \
# 0  11,10,8,14,9,7,13,12
#
#                                                                                                                                                                                                              Team1  \
# 0  Generic Memory One Player,Generic Memory One Player,Generic Memory One Player,Generic Memory One Player,Generic Memory One Player,Generic Memory One Player,Generic Memory One Player,Generic Memory One Player
#
#    Team1 Avg Score  Team1 New Avg Score  Team1 Min Score  Team1 Avg CC Dist  \
# 0          1.26773             2.652174         0.916667                0.0
#
#    Team1 New Avg CC Dist
# 0                    0.0

# %% [markdown]
# ### Total Results

# %%
classic_dataf = pd.read_csv('Data/Experiment2/7D1C_total.csv', index_col=0)

classic_dataf = classic_dataf.reset_index(drop=True)
classic_dataf.loc[:,:'SYS New CC Dist MIN']
# Out:
#              System ID  SYS MIN Score  SYS AVG Score  MIN of Team Avgs  \
# 0    Bitter Cooperator       0.988996       1.312375          1.312375
# 1           Cooperator       1.205782       1.425241          1.425241
# 2        Fourteen Coop       1.211735       1.425489          1.425489
# 3         Grim Trigger       0.892857       1.173533          1.173533
# 4        Thirteen Coop       1.205782       1.425241          1.425241
# 5          Tit for Tat       1.071429       1.260098          1.260098
# 6  Win-Stay Lose-Shift       0.916667       1.267730          1.267730
#
#    AVG of Team Mins  SYS CC Dist AVG  SYS CC Dist MIN  SYS New CC Dist AVG  \
# 0          0.988996         0.032313         0.032313             0.063545
# 1          1.205782         0.100482         0.100482             0.153846
# 2          1.211735         0.100978         0.100978             0.127090
# 3          0.892857         0.000000         0.000000             0.000000
# 4          1.205782         0.100482         0.100482             0.153846
# 5          1.071429         0.042517         0.042517             0.076923
# 6          0.916667         0.000000         0.000000             0.000000
#
#    SYS New CC Dist MIN
# 0             0.063545
# 1             0.153846
# 2             0.127090
# 3             0.000000
# 4             0.153846
# 5             0.076923
# 6             0.000000
