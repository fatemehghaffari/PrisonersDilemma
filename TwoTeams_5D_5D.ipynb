# %% [markdown]
# ## Tutorial: Using pd_exp to create experiments with Prisoner's Dilemma Tournaments
# This notebook walks through two different experimental setups to showcase the code functionality of the `pd_exp` module.

# %% [markdown]
# ## Strategies:
# 1 - Bitter Cooperator
#
# 2 - Cooperator
#
# 3 - Fourteen Coop
#
# 4 - Grim Trigger
#
# 5 - Thirteen Coop
#
# 6 - Tit For Tat
#
# 7 - Win-Stay Lose-Shift
#
# 8 - Defector
#
# 9 - Fourteen Defect
#
# 10 - Stubborn Defect
#
# 11 - Suspicious Tit For Tat
#
# 12 - Sucker Defect
#
# 13 - Two Defect
#
# 14 - Win-Shift Lose-Stay

# %%
# Local modules to import
import pd_exp
from helper_funcs import partitions
from settings import player_names, stag

# Other Python modules used
import pandas as pd
from pathlib import Path
import time, json
# Out:
# <generator object partitions at 0x7fe86c4a6728>

# %% [markdown]
# ### Experiment 5C5D: 5 Cooperators + 5 Defectors: Two teams

# %%
import axelrod as axl
p = Path('THEcoop_5_THEdef_5_2teams.txt')
p.touch()
with open(p, "r") as f:
    part_list = json.load(f)

# %%
print('Total count of teams: ',len(part_list))
print(part_list)
start_time = time.time()

print('Instantiate PD Experiments with different game types')
classic_pdExp = pd_exp.PdExp(part_list)

print('Running experiments and computing data')
classic_pdExp.run_experiments()

print('Save the data')
path = 'Data/Experiment2/'
classic_pdExp.save_data(path, 'ClassicPD_2teams_5TC5TD')  # CHANGE file_name string when necessary

print("--- %s seconds ---" % (time.time() - start_time))
# Out:
# Total count of teams:  3
# [[['Cooperator', 'Cooperator', 'Cooperator', 'Cooperator', 'Cooperator'], ['Defector', 'Defector', 'Defector', 'Defector', 'Defector']], [['Defector', 'Cooperator', 'Cooperator', 'Cooperator', 'Cooperator'], ['Cooperator', 'Defector', 'Defector', 'Defector', 'Defector']], [['Defector', 'Defector', 'Cooperator', 'Cooperator', 'Cooperator'], ['Cooperator', 'Cooperator', 'Defector', 'Defector', 'Defector']]]
# Instantiate PD Experiments with different game types
# Running experiments and computing data
# partition list:  [['Cooperator', 'Cooperator', 'Cooperator', 'Cooperator', 'Cooperator'], ['Defector', 'Defector', 'Defector', 'Defector', 'Defector']]
# Instantiating tournament object with these players:  Generic Memory One Player,Generic Memory One Player,Generic Memory One Player,Generic Memory One Player,Generic Memory One Player
# Playing matches: 100%|██████████| 15/15 [00:00<00:00, 826.37it/s]
# Analysing: 100%|██████████| 25/25 [00:00<00:00, 77.61it/s]
# Match length for each user against other users:  [[[3.0, 4.0, 8.0, 21.0, 12.0], [4.0, 20.0, 30.0, 2.0, 4.0], [8.0, 30.0, 6.0, 2.0, 10.0], [21.0, 2.0, 2.0, 16.0, 3.0], [12.0, 4.0, 10.0, 3.0, 6.0]]]
# Counting the number of CC states:
# player  1 states:
# {}
# {(C, C): 4}
# {(C, C): 8}
# {(C, C): 21}
# {(C, C): 12}
# player  2 states:
# {(C, C): 4}
# {}
# {(C, C): 30}
# {(C, C): 2}
# {(C, C): 4}
# player  3 states:
# {(C, C): 8}
# {(C, C): 30}
# {}
# {(C, C): 2}
# {(C, C): 10}
# player  4 states:
# {(C, C): 21}
# {(C, C): 2}
# {(C, C): 2}
# {}
# {(C, C): 3}
# player  5 states:
# {(C, C): 12}
# {(C, C): 4}
# {(C, C): 10}
# {(C, C): 3}
# {}
# The total number of CCs:  192
# Instantiating tournament object with these players:  Generic Memory One Player,Generic Memory One Player,Generic Memory One Player,Generic Memory One Player,Generic Memory One Player
#
# Playing matches: 100%|██████████| 15/15 [00:00<00:00, 729.23it/s]
# Analysing: 100%|██████████| 25/25 [00:00<00:00, 52.06it/s]
#
# Match length for each user against other users:  [[[3.0, 4.0, 8.0, 21.0, 12.0], [4.0, 20.0, 30.0, 2.0, 4.0], [8.0, 30.0, 6.0, 2.0, 10.0], [21.0, 2.0, 2.0, 16.0, 3.0], [12.0, 4.0, 10.0, 3.0, 6.0]]]
# Counting the number of CC states:
# player  1 states:
# {}
# {(D, D): 4}
# {(D, D): 8}
# {(D, D): 21}
# {(D, D): 12}
# player  2 states:
# {(D, D): 4}
# {}
# {(D, D): 30}
# {(D, D): 2}
# {(D, D): 4}
# player  3 states:
# {(D, D): 8}
# {(D, D): 30}
# {}
# {(D, D): 2}
# {(D, D): 10}
# player  4 states:
# {(D, D): 21}
# {(D, D): 2}
# {(D, D): 2}
# {}
# {(D, D): 3}
# player  5 states:
# {(D, D): 12}
# {(D, D): 4}
# {(D, D): 10}
# {(D, D): 3}
# {}
# The total number of CCs:  0
# str_list [['Cooperator', 'Cooperator', 'Cooperator', 'Cooperator', 'Cooperator'], ['Defector', 'Defector', 'Defector', 'Defector', 'Defector']]
# team list: [['Cooperator', 'Cooperator', 'Cooperator', 'Cooperator', 'Cooperator'], ['Defector', 'Defector', 'Defector', 'Defector', 'Defector']]
# str str: 2,2,2,2,2_8,8,8,8,8
# ***Processing number  1
# partition list:  [['Defector', 'Cooperator', 'Cooperator', 'Cooperator', 'Cooperator'], ['Cooperator', 'Defector', 'Defector', 'Defector', 'Defector']]
# Instantiating tournament object with these players:  Generic Memory One Player,Generic Memory One Player,Generic Memory One Player,Generic Memory One Player,Generic Memory One Player
# Playing matches: 100%|██████████| 15/15 [00:00<00:00, 1442.63it/s]
# Analysing: 100%|██████████| 25/25 [00:00<00:00, 117.58it/s]
# Match length for each user against other users:  [[[3.0, 4.0, 8.0, 21.0, 12.0], [4.0, 20.0, 30.0, 2.0, 4.0], [8.0, 30.0, 6.0, 2.0, 10.0], [21.0, 2.0, 2.0, 16.0, 3.0], [12.0, 4.0, 10.0, 3.0, 6.0]]]
# Counting the number of CC states:
# player  1 states:
# {}
# {(D, C): 4}
# {(D, C): 8}
# {(D, C): 21}
# {(D, C): 12}
# player  2 states:
# {(C, D): 4}
# {}
# {(C, C): 30}
# {(C, C): 2}
# {(C, C): 4}
# player  3 states:
# {(C, D): 8}
# {(C, C): 30}
# {}
# {(C, C): 2}
# {(C, C): 10}
# player  4 states:
# {(C, D): 21}
# {(C, C): 2}
# {(C, C): 2}
# {}
# {(C, C): 3}
# player  5 states:
# {(C, D): 12}
# {(C, C): 4}
# {(C, C): 10}
# {(C, C): 3}
# {}
# The total number of CCs:  102
# Instantiating tournament object with these players:  Generic Memory One Player,Generic Memory One Player,Generic Memory One Player,Generic Memory One Player,Generic Memory One Player
#
# Playing matches: 100%|██████████| 15/15 [00:00<00:00, 2614.58it/s]
# Analysing: 100%|██████████| 25/25 [00:00<00:00, 65.63it/s]
#
# Match length for each user against other users:  [[[3.0, 4.0, 8.0, 21.0, 12.0], [4.0, 20.0, 30.0, 2.0, 4.0], [8.0, 30.0, 6.0, 2.0, 10.0], [21.0, 2.0, 2.0, 16.0, 3.0], [12.0, 4.0, 10.0, 3.0, 6.0]]]
# Counting the number of CC states:
# player  1 states:
# {}
# {(C, D): 4}
# {(C, D): 8}
# {(C, D): 21}
# {(C, D): 12}
# player  2 states:
# {(D, C): 4}
# {}
# {(D, D): 30}
# {(D, D): 2}
# {(D, D): 4}
# player  3 states:
# {(D, C): 8}
# {(D, D): 30}
# {}
# {(D, D): 2}
# {(D, D): 10}
# player  4 states:
# {(D, C): 21}
# {(D, D): 2}
# {(D, D): 2}
# {}
# {(D, D): 3}
# player  5 states:
# {(D, C): 12}
# {(D, D): 4}
# {(D, D): 10}
# {(D, D): 3}
# {}
# The total number of CCs:  0
# str_list [['Defector', 'Cooperator', 'Cooperator', 'Cooperator', 'Cooperator'], ['Cooperator', 'Defector', 'Defector', 'Defector', 'Defector']]
# team list: [['Defector', 'Cooperator', 'Cooperator', 'Cooperator', 'Cooperator'], ['Cooperator', 'Defector', 'Defector', 'Defector', 'Defector']]
# str str: 8,2,2,2,2_2,8,8,8,8
# ***Processing number  2
# partition list:  [['Defector', 'Defector', 'Cooperator', 'Cooperator', 'Cooperator'], ['Cooperator', 'Cooperator', 'Defector', 'Defector', 'Defector']]
# Instantiating tournament object with these players:  Generic Memory One Player,Generic Memory One Player,Generic Memory One Player,Generic Memory One Player,Generic Memory One Player
# Playing matches: 100%|██████████| 15/15 [00:00<00:00, 451.66it/s]
# Analysing: 100%|██████████| 25/25 [00:00<00:00, 141.20it/s]
# Match length for each user against other users:  [[[3.0, 4.0, 8.0, 21.0, 12.0], [4.0, 20.0, 30.0, 2.0, 4.0], [8.0, 30.0, 6.0, 2.0, 10.0], [21.0, 2.0, 2.0, 16.0, 3.0], [12.0, 4.0, 10.0, 3.0, 6.0]]]
# Counting the number of CC states:
# player  1 states:
# {}
# {(D, D): 4}
# {(D, C): 8}
# {(D, C): 21}
# {(D, C): 12}
# player  2 states:
# {(D, D): 4}
# {}
# {(D, C): 30}
# {(D, C): 2}
# {(D, C): 4}
# player  3 states:
# {(C, D): 8}
# {(C, D): 30}
# {}
# {(C, C): 2}
# {(C, C): 10}
# player  4 states:
# {(C, D): 21}
# {(C, D): 2}
# {(C, C): 2}
# {}
# {(C, C): 3}
# player  5 states:
# {(C, D): 12}
# {(C, D): 4}
# {(C, C): 10}
# {(C, C): 3}
# {}
# The total number of CCs:  30
# Instantiating tournament object with these players:  Generic Memory One Player,Generic Memory One Player,Generic Memory One Player,Generic Memory One Player,Generic Memory One Player
#
# Playing matches: 100%|██████████| 15/15 [00:00<00:00, 476.37it/s]
# Analysing: 100%|██████████| 25/25 [00:00<00:00, 61.28it/s]
# Match length for each user against other users:  [[[3.0, 4.0, 8.0, 21.0, 12.0], [4.0, 20.0, 30.0, 2.0, 4.0], [8.0, 30.0, 6.0, 2.0, 10.0], [21.0, 2.0, 2.0, 16.0, 3.0], [12.0, 4.0, 10.0, 3.0, 6.0]]]
# Counting the number of CC states:
# player  1 states:
# {}
# {(C, C): 4}
# {(C, D): 8}
# {(C, D): 21}
# {(C, D): 12}
# player  2 states:
# {(C, C): 4}
# {}
# {(C, D): 30}
# {(C, D): 2}
# {(C, D): 4}
# player  3 states:
# {(D, C): 8}
# {(D, C): 30}
# {}
# {(D, D): 2}
# {(D, D): 10}
# player  4 states:
# {(D, C): 21}
# {(D, C): 2}
# {(D, D): 2}
# {}
# {(D, D): 3}
# player  5 states:
# {(D, C): 12}
# {(D, C): 4}
# {(D, D): 10}
# {(D, D): 3}
# {}
# The total number of CCs:  8
# str_list [['Defector', 'Defector', 'Cooperator', 'Cooperator', 'Cooperator'], ['Cooperator', 'Cooperator', 'Defector', 'Defector', 'Defector']]
# team list: [['Defector', 'Defector', 'Cooperator', 'Cooperator', 'Cooperator'], ['Cooperator', 'Cooperator', 'Defector', 'Defector', 'Defector']]
# str str: 8,8,2,2,2_2,2,8,8,8
# ***Processing number  3
# Save the data
# I am saving the data
# The file name is:  Data/Experiment2/ClassicPD_2teams_5TC5TD_RPST_3_1_0_5.csv
# --- 2.896587371826172 seconds ---

# %% [markdown]
# ### Experiment 7C5D: Comparing the results

# %%
classic_dataf = pd.read_csv('Data/Experiment2/ClassicPD_2teams_5TC5TD_RPST_3_1_0_5.csv', index_col=0)

classic_dataf = classic_dataf.reset_index(drop=True)
classic_dataf.loc[:,:'SYS New CC Dist MIN']
# Out:
#              System ID  SYS MIN Score  SYS AVG Score  MIN of Team Avgs  \
# 0  2,2,2,2,2_8,8,8,8,8           1.00            2.0               1.0
# 1  8,2,2,2,2_2,8,8,8,8           0.00            2.2               1.6
# 2  8,8,2,2,2_2,2,8,8,8           0.75            2.3               2.1
#
#    AVG of Team Mins  SYS CC Dist AVG  SYS CC Dist MIN  SYS New CC Dist AVG  \
# 0             2.000              0.5              0.0             0.500000
# 1             1.125              0.3              0.0             0.265625
# 2             1.125              0.2              0.1             0.098958
#
#    SYS New CC Dist MIN
# 0             0.000000
# 1             0.000000
# 2             0.041667

# %%
with pd.option_context('display.max_rows', None, 'display.max_columns', None, 'display.max_colwidth', None):  # more options can be specified also
    display(classic_dataf[['System ID', 'Team1 Avg Score', 'Team1 New Avg Score', 
       'Team1 Min Score', 'Team1 Avg CC Dist', 'Team1 New Avg CC Dist', 'Team2 Avg Score', 'Team2 New Avg Score', 
       'Team2 Min Score', 'Team2 Avg CC Dist', 'Team2 New Avg CC Dist']])
# Out:
#              System ID  Team1 Avg Score  Team1 New Avg Score  Team1 Min Score  \
# 0  2,2,2,2,2_8,8,8,8,8              3.0              6.00000             3.00
# 1  8,2,2,2,2_2,8,8,8,8              2.8              5.53125             2.25
# 2  8,8,2,2,2_2,2,8,8,8              2.5              5.03125             1.50
#
#    Team1 Avg CC Dist  Team1 New Avg CC Dist  Team2 Avg Score  \
# 0                1.0                1.00000              1.0
# 1                0.6                0.53125              1.6
# 2                0.3                0.15625              2.1
#
#    Team2 New Avg Score  Team2 Min Score  Team2 Avg CC Dist  \
# 0             2.000000             1.00                0.0
# 1             3.406250             0.00                0.0
# 2             4.572917             0.75                0.1
#
#    Team2 New Avg CC Dist
# 0               0.000000
# 1               0.000000
# 2               0.041667
