# %% [markdown]
# ## Tutorial: Using pd_exp to create experiments with Prisoner's Dilemma Tournaments
# This notebook walks through two different experimental setups to showcase the code functionality of the `pd_exp` module.

# %%
# Local modules to import
import pd_exp
from helper_funcs import partitions
from settings import player_names, stag

# Other Python modules used
import pandas as pd
from pathlib import Path
import time, json

# %% [markdown]
# ### 7C + Fourteen Defect (1, 1, 1, 0)

# %%
import axelrod as axl
players = ['Bitter Cooperator', 'Cooperator', 'Fourteen Coop', 'Grim Trigger', 'Thirteen Coop', 'Tit For Tat', 'Win-Stay Lose-Shift', 'Fourteen Defect']
part_list = list(partitions(players,8))
p = Path('7_coop_Fourteen_Defect.txt')
p.touch()
with open(p, "w") as f:
    json.dump(part_list, f)

# %%
# part_list = part_list[:3] # Let's just consider 3 different teams
# part_list = [[('Cooperator', 'Defector'), ('Cooperator', 'Cooperator'), ('Defector', 'Defector')]]
print('Total count of teams: ',len(part_list))
print(part_list)
start_time = time.time()

print('Instantiate PD Experiments with different game types')
classic_pdExp = pd_exp.PdExp(part_list)
# stag_pdExp = pd_exp.PdExp(part_list,game_type=stag)

print('Running experiments and computing data')
classic_pdExp.run_experiments()
# stag_pdExp.run_experiments()

print('Save the data')
path = 'Data/Experiment2/'
classic_pdExp.save_data(path, 'ClassicPD_7C_Fourteen_Defect')  # CHANGE file_name string when necessary
# stag_pdExp.save_data(path, 'StagHunt_4x3_12uniq_DEMO_RPST_5_1_0_3')  # CHANGE file_name string when necessary

print("--- %s seconds ---" % (time.time() - start_time))
# Out:
# Total count of teams:  1
# [[('Cooperator', 'Grim Trigger', 'Tit For Tat', 'Fourteen Coop', 'Fourteen Defect', 'Win-Stay Lose-Shift', 'Thirteen Coop', 'Bitter Cooperator')]]
# Instantiate PD Experiments with different game types
# Running experiments and computing data
# partition list:  [('Cooperator', 'Grim Trigger', 'Tit For Tat', 'Fourteen Coop', 'Fourteen Defect', 'Win-Stay Lose-Shift', 'Thirteen Coop', 'Bitter Cooperator')]
# Instantiating tournament object with these players:  Generic Memory One Player,Generic Memory One Player,Generic Memory One Player,Generic Memory One Player,Generic Memory One Player,Generic Memory One Player,Generic Memory One Player,Generic Memory One Player
# Playing matches: 100%|██████████| 36/36 [00:00<00:00, 717.26it/s]
# Analysing: 100%|██████████| 25/25 [00:00<00:00, 79.27it/s]
# Match length for each user against other users:  [[[3.0, 4.0, 8.0, 21.0, 12.0, 20.0, 30.0, 2.0], [4.0, 4.0, 6.0, 2.0, 10.0, 16.0, 3.0, 6.0], [8.0, 6.0, 2.0, 12.0, 14.0, 21.0, 8.0, 6.0], [21.0, 2.0, 12.0, 4.0, 22.0, 12.0, 9.0, 17.0], [12.0, 10.0, 14.0, 22.0, 4.0, 3.0, 4.0, 1.0], [20.0, 16.0, 21.0, 12.0, 3.0, 3.0, 8.0, 21.0], [30.0, 3.0, 8.0, 9.0, 4.0, 8.0, 6.0, 1.0], [2.0, 6.0, 6.0, 17.0, 1.0, 21.0, 1.0, 2.0]]]
# Counting the number of CC states:
# player  1 states:
# {}
# {(C, C): 4}
# {(C, C): 8}
# {(C, C): 21}
# {(C, C): 11, (C, D): 1}
# {(C, C): 20}
# {(C, C): 30}
# {(C, C): 2}
# player  2 states:
# {(C, C): 4}
# {}
# {(C, C): 6}
# {(C, C): 2}
# {(C, D): 1, (D, C): 9}
# {(C, C): 16}
# {(C, C): 3}
# {(C, C): 6}
# player  3 states:
# {(C, C): 8}
# {(C, C): 6}
# {}
# {(C, C): 12}
# {(C, C): 12, (C, D): 1, (D, C): 1}
# {(C, C): 21}
# {(C, C): 8}
# {(C, C): 6}
# player  4 states:
# {(C, C): 21}
# {(C, C): 2}
# {(C, C): 12}
# {}
# {(C, C): 21, (C, D): 1}
# {(C, C): 12}
# {(C, C): 9}
# {(C, C): 17}
# player  5 states:
# {(C, C): 11, (D, C): 1}
# {(C, D): 9, (D, C): 1}
# {(C, C): 12, (C, D): 1, (D, C): 1}
# {(C, C): 21, (D, C): 1}
# {}
# {(C, D): 2, (D, C): 1}
# {(C, C): 3, (D, C): 1}
# {(D, C): 1}
# player  6 states:
# {(C, C): 20}
# {(C, C): 16}
# {(C, C): 21}
# {(C, C): 12}
# {(C, D): 1, (D, C): 2}
# {}
# {(C, C): 8}
# {(C, C): 21}
# player  7 states:
# {(C, C): 30}
# {(C, C): 3}
# {(C, C): 8}
# {(C, C): 9}
# {(C, C): 3, (C, D): 1}
# {(C, C): 8}
# {}
# {(C, C): 1}
# player  8 states:
# {(C, C): 2}
# {(C, C): 6}
# {(C, C): 6}
# {(C, C): 17}
# {(C, D): 1}
# {(C, C): 21}
# {(C, C): 1}
# {}
# The total number of CCs:  560
# str_list [('Cooperator', 'Grim Trigger', 'Tit For Tat', 'Fourteen Coop', 'Fourteen Defect', 'Win-Stay Lose-Shift', 'Thirteen Coop', 'Bitter Cooperator')]
# team list: [('Cooperator', 'Grim Trigger', 'Tit For Tat', 'Fourteen Coop', 'Fourteen Defect', 'Win-Stay Lose-Shift', 'Thirteen Coop', 'Bitter Cooperator')]
# str str: 2,4,6,3,9,7,5,1
# ***Processing number  1
# Save the data
# I am saving the data
# The file name is:  Data/Experiment2/ClassicPD_7C_Fourteen_Defect_RPST_3_1_0_5.csv
# --- 0.4708082675933838 seconds ---

# %% [markdown]
# ### 7C + Fourteen Defect Results

# %%
# Let's compare the results
# Retrieve the stored data
classic_dataf = pd.read_csv('Data/Experiment2/ClassicPD_7C_Fourteen_Defect_RPST_3_1_0_5.csv', index_col=0)

# Reset the index to accurately count the total systems
classic_dataf = classic_dataf.reset_index(drop=True)

# %%
classic_dataf.loc[:,:'SYS New CC Dist MIN']
# Out:
#          System ID  SYS MIN Score  SYS AVG Score  MIN of Team Avgs  \
# 0  2,4,6,3,9,7,5,1       2.571429       2.937113          2.937113
#
#    AVG of Team Mins  SYS CC Dist AVG  SYS CC Dist MIN  SYS New CC Dist AVG  \
# 0          2.571429         0.874227         0.874227             0.936455
#
#    SYS New CC Dist MIN
# 0             0.936455

# %%
with pd.option_context('display.max_rows', None, 'display.max_columns', None, 'display.max_colwidth', None):  # more options can be specified also
    display(classic_dataf[['System ID', 'Team1', 'Team1 Avg Score', 'Team1 New Avg Score', 
       'Team1 Min Score', 'Team1 Avg CC Dist', 'Team1 New Avg CC Dist']])
# Out:
#          System ID  \
# 0  2,4,6,3,9,7,5,1
#
#                                                                                                                                                                                                              Team1  \
# 0  Generic Memory One Player,Generic Memory One Player,Generic Memory One Player,Generic Memory One Player,Generic Memory One Player,Generic Memory One Player,Generic Memory One Player,Generic Memory One Player
#
#    Team1 Avg Score  Team1 New Avg Score  Team1 Min Score  Team1 Avg CC Dist  \
# 0         2.937113             5.936455         2.571429           0.874227
#
#    Team1 New Avg CC Dist
# 0               0.936455

# %% [markdown]
# ### 7C + Stubborn Defect Results (1, 0, 0, 0)

# %%
import axelrod as axl
from axelrod.action import Action

players = ['Bitter Cooperator', 'Cooperator', 'Fourteen Coop', 'Grim Trigger', 'Thirteen Coop', 'Tit For Tat', 'Win-Stay Lose-Shift', 'Stubborn Defect']
part_list = list(partitions(players,8))

p = Path('7_coop_Stubborn_Defect.txt')
p.touch()
with open(p, "w") as f:
    json.dump(part_list, f)

# %%
print('Total count of teams: ',len(part_list))
print(part_list)
start_time = time.time()

print('Instantiate PD Experiments with different game types')
classic_pdExp = pd_exp.PdExp(part_list)

print('Running experiments and computing data')
classic_pdExp.run_experiments()

print('Save the data')
path = 'Data/Experiment2/'
classic_pdExp.save_data(path, 'ClassicPD_7C_Stubborn_Defect')  # CHANGE file_name string when necessary

print("--- %s seconds ---" % (time.time() - start_time))
# Out:
# Total count of teams:  1
# [[('Cooperator', 'Grim Trigger', 'Tit For Tat', 'Fourteen Coop', 'Win-Stay Lose-Shift', 'Stubborn Defect', 'Thirteen Coop', 'Bitter Cooperator')]]
# Instantiate PD Experiments with different game types
# Running experiments and computing data
# partition list:  [('Cooperator', 'Grim Trigger', 'Tit For Tat', 'Fourteen Coop', 'Win-Stay Lose-Shift', 'Stubborn Defect', 'Thirteen Coop', 'Bitter Cooperator')]
# Instantiating tournament object with these players:  Generic Memory One Player,Generic Memory One Player,Generic Memory One Player,Generic Memory One Player,Generic Memory One Player,Generic Memory One Player,Generic Memory One Player,Generic Memory One Player
# Playing matches: 100%|██████████| 36/36 [00:00<00:00, 831.91it/s]
# Analysing: 100%|██████████| 25/25 [00:00<00:00, 51.73it/s]
# Match length for each user against other users:  [[[3.0, 4.0, 8.0, 21.0, 12.0, 20.0, 30.0, 2.0], [4.0, 4.0, 6.0, 2.0, 10.0, 16.0, 3.0, 6.0], [8.0, 6.0, 2.0, 12.0, 14.0, 21.0, 8.0, 6.0], [21.0, 2.0, 12.0, 4.0, 22.0, 12.0, 9.0, 17.0], [12.0, 10.0, 14.0, 22.0, 4.0, 3.0, 4.0, 1.0], [20.0, 16.0, 21.0, 12.0, 3.0, 3.0, 8.0, 21.0], [30.0, 3.0, 8.0, 9.0, 4.0, 8.0, 6.0, 1.0], [2.0, 6.0, 6.0, 17.0, 1.0, 21.0, 1.0, 2.0]]]
# Counting the number of CC states:
# player  1 states:
# {}
# {(C, C): 4}
# {(C, C): 8}
# {(C, C): 21}
# {(C, C): 12}
# {(C, D): 20}
# {(C, C): 30}
# {(C, C): 2}
# player  2 states:
# {(C, C): 4}
# {}
# {(C, C): 6}
# {(C, C): 2}
# {(C, C): 10}
# {(C, D): 1, (D, D): 15}
# {(C, C): 3}
# {(C, C): 6}
# player  3 states:
# {(C, C): 8}
# {(C, C): 6}
# {}
# {(C, C): 12}
# {(C, C): 14}
# {(C, D): 1, (D, D): 20}
# {(C, C): 8}
# {(C, C): 6}
# player  4 states:
# {(C, C): 21}
# {(C, C): 2}
# {(C, C): 12}
# {}
# {(C, C): 22}
# {(C, D): 12}
# {(C, C): 9}
# {(C, C): 17}
# player  5 states:
# {(C, C): 12}
# {(C, C): 10}
# {(C, C): 14}
# {(C, C): 22}
# {}
# {(C, D): 2, (D, D): 1}
# {(C, C): 4}
# {(C, C): 1}
# player  6 states:
# {(D, C): 20}
# {(D, C): 1, (D, D): 15}
# {(D, C): 1, (D, D): 20}
# {(D, C): 12}
# {(D, C): 2, (D, D): 1}
# {}
# {(D, C): 8}
# {(D, C): 11, (D, D): 10}
# player  7 states:
# {(C, C): 30}
# {(C, C): 3}
# {(C, C): 8}
# {(C, C): 9}
# {(C, C): 4}
# {(C, D): 8}
# {}
# {(C, C): 1}
# player  8 states:
# {(C, C): 2}
# {(C, C): 6}
# {(C, C): 6}
# {(C, C): 17}
# {(C, C): 1}
# {(C, D): 11, (D, D): 10}
# {(C, C): 1}
# {}
# The total number of CCs:  396
# str_list [('Cooperator', 'Grim Trigger', 'Tit For Tat', 'Fourteen Coop', 'Win-Stay Lose-Shift', 'Stubborn Defect', 'Thirteen Coop', 'Bitter Cooperator')]
# team list: [('Cooperator', 'Grim Trigger', 'Tit For Tat', 'Fourteen Coop', 'Win-Stay Lose-Shift', 'Stubborn Defect', 'Thirteen Coop', 'Bitter Cooperator')]
# str str: 2,4,6,3,7,10,5,1
# ***Processing number  1
# Save the data
# I am saving the data
# The file name is:  Data/Experiment2/ClassicPD_7C_Stubborn_Defect_RPST_3_1_0_5.csv
# --- 0.6699726581573486 seconds ---

# %% [markdown]
# ### 7C + Stubborn Defect Results

# %%
# Let's compare the results
# Retrieve the stored data
classic_dataf = pd.read_csv('Data/Experiment2/ClassicPD_7C_Stubborn_Defect_RPST_3_1_0_5.csv', index_col=0)

# Reset the index to accurately count the total systems
classic_dataf = classic_dataf.reset_index(drop=True)
classic_dataf.loc[:,:'SYS New CC Dist MIN']
# Out:
#           System ID  SYS MIN Score  SYS AVG Score  MIN of Team Avgs  \
# 0  2,4,6,3,7,10,5,1       2.571429       2.730389          2.730389
#
#    AVG of Team Mins  SYS CC Dist AVG  SYS CC Dist MIN  SYS New CC Dist AVG  \
# 0          2.571429             0.75             0.75             0.662207
#
#    SYS New CC Dist MIN
# 0             0.662207

# %%
with pd.option_context('display.max_rows', None, 'display.max_columns', None, 'display.max_colwidth', None):  # more options can be specified also
    display(classic_dataf[['System ID', 'Team1', 'Team1 Avg Score', 'Team1 New Avg Score', 
       'Team1 Min Score', 'Team1 Avg CC Dist', 'Team1 New Avg CC Dist']])
# Out:
#           System ID  \
# 0  2,4,6,3,7,10,5,1
#
#                                                                                                                                                                                                              Team1  \
# 0  Generic Memory One Player,Generic Memory One Player,Generic Memory One Player,Generic Memory One Player,Generic Memory One Player,Generic Memory One Player,Generic Memory One Player,Generic Memory One Player
#
#    Team1 Avg Score  Team1 New Avg Score  Team1 Min Score  Team1 Avg CC Dist  \
# 0         2.730389             5.200669         2.571429               0.75
#
#    Team1 New Avg CC Dist
# 0               0.662207

# %% [markdown]
# ### 7C + Defector (0, 0, 0, 0)

# %%
import axelrod as axl
players = ['Bitter Cooperator', 'Cooperator', 'Fourteen Coop', 'Grim Trigger', 'Thirteen Coop', 'Tit For Tat', 'Win-Stay Lose-Shift', 'Defector']
part_list = list(partitions(players,8))

p = Path('7_coop_Defector.txt')
p.touch()
with open(p, "w") as f:
    json.dump(part_list, f)

# %%
print('Total count of teams: ',len(part_list))
print(part_list)
start_time = time.time()

print('Instantiate PD Experiments with different game types')
classic_pdExp = pd_exp.PdExp(part_list)

print('Running experiments and computing data')
classic_pdExp.run_experiments()

print('Save the data')
path = 'Data/Experiment2/'
classic_pdExp.save_data(path, 'ClassicPD_7C_Defector')  # CHANGE file_name string when necessary

print("--- %s seconds ---" % (time.time() - start_time))
# Out:
# Total count of teams:  1
# [[('Cooperator', 'Grim Trigger', 'Tit For Tat', 'Fourteen Coop', 'Win-Stay Lose-Shift', 'Defector', 'Thirteen Coop', 'Bitter Cooperator')]]
# Instantiate PD Experiments with different game types
# Running experiments and computing data
# partition list:  [('Cooperator', 'Grim Trigger', 'Tit For Tat', 'Fourteen Coop', 'Win-Stay Lose-Shift', 'Defector', 'Thirteen Coop', 'Bitter Cooperator')]
# Instantiating tournament object with these players:  Generic Memory One Player,Generic Memory One Player,Generic Memory One Player,Generic Memory One Player,Generic Memory One Player,Generic Memory One Player,Generic Memory One Player,Generic Memory One Player
# Playing matches: 100%|██████████| 36/36 [00:00<00:00, 455.76it/s]
# Analysing: 100%|██████████| 25/25 [00:00<00:00, 68.73it/s]
#
# Match length for each user against other users:  [[[3.0, 4.0, 8.0, 21.0, 12.0, 20.0, 30.0, 2.0], [4.0, 4.0, 6.0, 2.0, 10.0, 16.0, 3.0, 6.0], [8.0, 6.0, 2.0, 12.0, 14.0, 21.0, 8.0, 6.0], [21.0, 2.0, 12.0, 4.0, 22.0, 12.0, 9.0, 17.0], [12.0, 10.0, 14.0, 22.0, 4.0, 3.0, 4.0, 1.0], [20.0, 16.0, 21.0, 12.0, 3.0, 3.0, 8.0, 21.0], [30.0, 3.0, 8.0, 9.0, 4.0, 8.0, 6.0, 1.0], [2.0, 6.0, 6.0, 17.0, 1.0, 21.0, 1.0, 2.0]]]
# Counting the number of CC states:
# player  1 states:
# {}
# {(C, C): 4}
# {(C, C): 8}
# {(C, C): 21}
# {(C, C): 12}
# {(C, D): 20}
# {(C, C): 30}
# {(C, C): 2}
# player  2 states:
# {(C, C): 4}
# {}
# {(C, C): 6}
# {(C, C): 2}
# {(C, C): 10}
# {(C, D): 1, (D, D): 15}
# {(C, C): 3}
# {(C, C): 6}
# player  3 states:
# {(C, C): 8}
# {(C, C): 6}
# {}
# {(C, C): 12}
# {(C, C): 14}
# {(C, D): 1, (D, D): 20}
# {(C, C): 8}
# {(C, C): 6}
# player  4 states:
# {(C, C): 21}
# {(C, C): 2}
# {(C, C): 12}
# {}
# {(C, C): 22}
# {(C, D): 12}
# {(C, C): 9}
# {(C, C): 17}
# player  5 states:
# {(C, C): 12}
# {(C, C): 10}
# {(C, C): 14}
# {(C, C): 22}
# {}
# {(C, D): 2, (D, D): 1}
# {(C, C): 4}
# {(C, C): 1}
# player  6 states:
# {(D, C): 20}
# {(D, C): 1, (D, D): 15}
# {(D, C): 1, (D, D): 20}
# {(D, C): 12}
# {(D, C): 2, (D, D): 1}
# {}
# {(D, C): 8}
# {(D, C): 11, (D, D): 10}
# player  7 states:
# {(C, C): 30}
# {(C, C): 3}
# {(C, C): 8}
# {(C, C): 9}
# {(C, C): 4}
# {(C, D): 8}
# {}
# {(C, C): 1}
# player  8 states:
# {(C, C): 2}
# {(C, C): 6}
# {(C, C): 6}
# {(C, C): 17}
# {(C, C): 1}
# {(C, D): 11, (D, D): 10}
# {(C, C): 1}
# {}
# The total number of CCs:  396
# str_list [('Cooperator', 'Grim Trigger', 'Tit For Tat', 'Fourteen Coop', 'Win-Stay Lose-Shift', 'Defector', 'Thirteen Coop', 'Bitter Cooperator')]
# team list: [('Cooperator', 'Grim Trigger', 'Tit For Tat', 'Fourteen Coop', 'Win-Stay Lose-Shift', 'Defector', 'Thirteen Coop', 'Bitter Cooperator')]
# str str: 2,4,6,3,7,8,5,1
# ***Processing number  1
# Save the data
# I am saving the data
# The file name is:  Data/Experiment2/ClassicPD_7C_Defector_RPST_3_1_0_5.csv
# --- 0.629401683807373 seconds ---

# %% [markdown]
# ### 7C + Defector Results

# %%
classic_dataf = pd.read_csv('Data/Experiment2/ClassicPD_7C_Defector_RPST_3_1_0_5.csv', index_col=0)

classic_dataf = classic_dataf.reset_index(drop=True)
classic_dataf.loc[:,:'SYS New CC Dist MIN']
# Out:
#          System ID  SYS MIN Score  SYS AVG Score  MIN of Team Avgs  \
# 0  2,4,6,3,7,8,5,1       2.571429       2.730389          2.730389
#
#    AVG of Team Mins  SYS CC Dist AVG  SYS CC Dist MIN  SYS New CC Dist AVG  \
# 0          2.571429             0.75             0.75             0.662207
#
#    SYS New CC Dist MIN
# 0             0.662207

# %%
with pd.option_context('display.max_rows', None, 'display.max_columns', None, 'display.max_colwidth', None):  # more options can be specified also
    display(classic_dataf[['System ID', 'Team1', 'Team1 Avg Score', 'Team1 New Avg Score', 
       'Team1 Min Score', 'Team1 Avg CC Dist', 'Team1 New Avg CC Dist']])
# Out:
#          System ID  \
# 0  2,4,6,3,7,8,5,1
#
#                                                                                                                                                                                                              Team1  \
# 0  Generic Memory One Player,Generic Memory One Player,Generic Memory One Player,Generic Memory One Player,Generic Memory One Player,Generic Memory One Player,Generic Memory One Player,Generic Memory One Player
#
#    Team1 Avg Score  Team1 New Avg Score  Team1 Min Score  Team1 Avg CC Dist  \
# 0         2.730389             5.200669         2.571429               0.75
#
#    Team1 New Avg CC Dist
# 0               0.662207

# %% [markdown]
# ### 7C + Suspicious Tit For Tat (1, 0, 1, 0)

# %%
import axelrod as axl
players = ['Bitter Cooperator', 'Cooperator', 'Fourteen Coop', 'Grim Trigger', 'Thirteen Coop', 'Tit For Tat', 'Win-Stay Lose-Shift', 'Suspicious Tit For Tat']
part_list = list(partitions(players,8))

p = Path('7_coop_Suspicious_Tit_For_Tat.txt')
p.touch()
with open(p, "w") as f:
    json.dump(part_list, f)

# %%
print('Total count of teams: ',len(part_list))
print(part_list)
start_time = time.time()

print('Instantiate PD Experiments with different game types')
classic_pdExp = pd_exp.PdExp(part_list)

print('Running experiments and computing data')
classic_pdExp.run_experiments()

print('Save the data')
path = 'Data/Experiment2/'
classic_pdExp.save_data(path, 'ClassicPD_7C_Suspicious_Tit_For_Tat')  # CHANGE file_name string when necessary

print("--- %s seconds ---" % (time.time() - start_time))
# Out:
# Total count of teams:  1
# [[('Cooperator', 'Grim Trigger', 'Tit For Tat', 'Fourteen Coop', 'Win-Stay Lose-Shift', 'Suspicious Tit For Tat', 'Thirteen Coop', 'Bitter Cooperator')]]
# Instantiate PD Experiments with different game types
# Running experiments and computing data
# partition list:  [('Cooperator', 'Grim Trigger', 'Tit For Tat', 'Fourteen Coop', 'Win-Stay Lose-Shift', 'Suspicious Tit For Tat', 'Thirteen Coop', 'Bitter Cooperator')]
# Instantiating tournament object with these players:  Generic Memory One Player,Generic Memory One Player,Generic Memory One Player,Generic Memory One Player,Generic Memory One Player,Generic Memory One Player,Generic Memory One Player,Generic Memory One Player
# Playing matches: 100%|██████████| 36/36 [00:00<00:00, 1215.58it/s]
# Analysing: 100%|██████████| 25/25 [00:00<00:00, 53.24it/s]
# Match length for each user against other users:  [[[3.0, 4.0, 8.0, 21.0, 12.0, 20.0, 30.0, 2.0], [4.0, 4.0, 6.0, 2.0, 10.0, 16.0, 3.0, 6.0], [8.0, 6.0, 2.0, 12.0, 14.0, 21.0, 8.0, 6.0], [21.0, 2.0, 12.0, 4.0, 22.0, 12.0, 9.0, 17.0], [12.0, 10.0, 14.0, 22.0, 4.0, 3.0, 4.0, 1.0], [20.0, 16.0, 21.0, 12.0, 3.0, 3.0, 8.0, 21.0], [30.0, 3.0, 8.0, 9.0, 4.0, 8.0, 6.0, 1.0], [2.0, 6.0, 6.0, 17.0, 1.0, 21.0, 1.0, 2.0]]]
# Counting the number of CC states:
# player  1 states:
# {}
# {(C, C): 4}
# {(C, C): 8}
# {(C, C): 21}
# {(C, C): 12}
# {(C, C): 19, (C, D): 1}
# {(C, C): 30}
# {(C, C): 2}
# player  2 states:
# {(C, C): 4}
# {}
# {(C, C): 6}
# {(C, C): 2}
# {(C, C): 10}
# {(C, D): 1, (D, C): 1, (D, D): 14}
# {(C, C): 3}
# {(C, C): 6}
# player  3 states:
# {(C, C): 8}
# {(C, C): 6}
# {}
# {(C, C): 12}
# {(C, C): 14}
# {(C, D): 11, (D, C): 10}
# {(C, C): 8}
# {(C, C): 6}
# player  4 states:
# {(C, C): 21}
# {(C, C): 2}
# {(C, C): 12}
# {}
# {(C, C): 22}
# {(C, C): 11, (C, D): 1}
# {(C, C): 9}
# {(C, C): 17}
# player  5 states:
# {(C, C): 12}
# {(C, C): 10}
# {(C, C): 14}
# {(C, C): 22}
# {}
# {(C, D): 1, (D, C): 1, (D, D): 1}
# {(C, C): 4}
# {(C, C): 1}
# player  6 states:
# {(C, C): 19, (D, C): 1}
# {(C, D): 1, (D, C): 1, (D, D): 14}
# {(C, D): 10, (D, C): 11}
# {(C, C): 11, (D, C): 1}
# {(C, D): 1, (D, C): 1, (D, D): 1}
# {}
# {(C, C): 7, (D, C): 1}
# {(C, D): 10, (D, C): 11}
# player  7 states:
# {(C, C): 30}
# {(C, C): 3}
# {(C, C): 8}
# {(C, C): 9}
# {(C, C): 4}
# {(C, C): 7, (C, D): 1}
# {}
# {(C, C): 1}
# player  8 states:
# {(C, C): 2}
# {(C, C): 6}
# {(C, C): 6}
# {(C, C): 17}
# {(C, C): 1}
# {(C, D): 11, (D, C): 10}
# {(C, C): 1}
# {}
# The total number of CCs:  470
# str_list [('Cooperator', 'Grim Trigger', 'Tit For Tat', 'Fourteen Coop', 'Win-Stay Lose-Shift', 'Suspicious Tit For Tat', 'Thirteen Coop', 'Bitter Cooperator')]
# team list: [('Cooperator', 'Grim Trigger', 'Tit For Tat', 'Fourteen Coop', 'Win-Stay Lose-Shift', 'Suspicious Tit For Tat', 'Thirteen Coop', 'Bitter Cooperator')]
# str str: 2,4,6,3,7,11,5,1
# ***Processing number  1
# Save the data
# I am saving the data
# The file name is:  Data/Experiment2/ClassicPD_7C_Suspicious_Tit_For_Tat_RPST_3_1_0_5.csv
# --- 0.6570799350738525 seconds ---

# %% [markdown]
# ### 7C + Suspicious Tit For Tat results

# %%
classic_dataf = pd.read_csv('Data/Experiment2/ClassicPD_7C_Suspicious_Tit_For_Tat_RPST_3_1_0_5.csv', index_col=0)

classic_dataf = classic_dataf.reset_index(drop=True)
classic_dataf.loc[:,:'SYS New CC Dist MIN']
# Out:
#           System ID  SYS MIN Score  SYS AVG Score  MIN of Team Avgs  \
# 0  2,4,6,3,7,11,5,1        2.56318       2.859226          2.859226
#
#    AVG of Team Mins  SYS CC Dist AVG  SYS CC Dist MIN  SYS New CC Dist AVG  \
# 0           2.56318         0.847917         0.847917             0.785953
#
#    SYS New CC Dist MIN
# 0             0.785953

# %%
with pd.option_context('display.max_rows', None, 'display.max_columns', None, 'display.max_colwidth', None):  # more options can be specified also
    display(classic_dataf[['System ID', 'Team1', 'Team1 Avg Score', 'Team1 New Avg Score', 
       'Team1 Min Score', 'Team1 Avg CC Dist', 'Team1 New Avg CC Dist']])
# Out:
#           System ID  \
# 0  2,4,6,3,7,11,5,1
#
#                                                                                                                                                                                                              Team1  \
# 0  Generic Memory One Player,Generic Memory One Player,Generic Memory One Player,Generic Memory One Player,Generic Memory One Player,Generic Memory One Player,Generic Memory One Player,Generic Memory One Player
#
#    Team1 Avg Score  Team1 New Avg Score  Team1 Min Score  Team1 Avg CC Dist  \
# 0         2.859226             5.635452          2.56318           0.847917
#
#    Team1 New Avg CC Dist
# 0               0.785953

# %% [markdown]
# ### 7C + Sucker Defect (0, 1, 0, 0)

# %%
import axelrod as axl
players = ['Bitter Cooperator', 'Cooperator', 'Fourteen Coop', 'Grim Trigger', 'Thirteen Coop', 'Tit For Tat', 'Win-Stay Lose-Shift', 'Sucker Defect']
part_list = list(partitions(players,8))

p = Path('7_coop_Sucker_Defect.txt')
p.touch()
with open(p, "w") as f:
    json.dump(part_list, f)

# %%
print('Total count of teams: ',len(part_list))
print(part_list)
start_time = time.time()

print('Instantiate PD Experiments with different game types')
classic_pdExp = pd_exp.PdExp(part_list)

print('Running experiments and computing data')
classic_pdExp.run_experiments()

print('Save the data')
path = 'Data/Experiment2/'
classic_pdExp.save_data(path, 'ClassicPD_7C_Sucker_Defect')  # CHANGE file_name string when necessary

print("--- %s seconds ---" % (time.time() - start_time))
# Out:
# Total count of teams:  1
# [[('Cooperator', 'Grim Trigger', 'Tit For Tat', 'Fourteen Coop', 'Sucker Defect', 'Win-Stay Lose-Shift', 'Thirteen Coop', 'Bitter Cooperator')]]
# Instantiate PD Experiments with different game types
# Running experiments and computing data
# partition list:  [('Cooperator', 'Grim Trigger', 'Tit For Tat', 'Fourteen Coop', 'Sucker Defect', 'Win-Stay Lose-Shift', 'Thirteen Coop', 'Bitter Cooperator')]
# Instantiating tournament object with these players:  Generic Memory One Player,Generic Memory One Player,Generic Memory One Player,Generic Memory One Player,Generic Memory One Player,Generic Memory One Player,Generic Memory One Player,Generic Memory One Player
# Playing matches: 100%|██████████| 36/36 [00:00<00:00, 1000.20it/s]
# Analysing: 100%|██████████| 25/25 [00:00<00:00, 54.92it/s]
# Match length for each user against other users:  [[[3.0, 4.0, 8.0, 21.0, 12.0, 20.0, 30.0, 2.0], [4.0, 4.0, 6.0, 2.0, 10.0, 16.0, 3.0, 6.0], [8.0, 6.0, 2.0, 12.0, 14.0, 21.0, 8.0, 6.0], [21.0, 2.0, 12.0, 4.0, 22.0, 12.0, 9.0, 17.0], [12.0, 10.0, 14.0, 22.0, 4.0, 3.0, 4.0, 1.0], [20.0, 16.0, 21.0, 12.0, 3.0, 3.0, 8.0, 21.0], [30.0, 3.0, 8.0, 9.0, 4.0, 8.0, 6.0, 1.0], [2.0, 6.0, 6.0, 17.0, 1.0, 21.0, 1.0, 2.0]]]
# Counting the number of CC states:
# player  1 states:
# {}
# {(C, C): 4}
# {(C, C): 8}
# {(C, C): 21}
# {(C, D): 12}
# {(C, C): 20}
# {(C, C): 30}
# {(C, C): 2}
# player  2 states:
# {(C, C): 4}
# {}
# {(C, C): 6}
# {(C, C): 2}
# {(C, D): 1, (D, D): 9}
# {(C, C): 16}
# {(C, C): 3}
# {(C, C): 6}
# player  3 states:
# {(C, C): 8}
# {(C, C): 6}
# {}
# {(C, C): 12}
# {(C, D): 1, (D, D): 13}
# {(C, C): 21}
# {(C, C): 8}
# {(C, C): 6}
# player  4 states:
# {(C, C): 21}
# {(C, C): 2}
# {(C, C): 12}
# {}
# {(C, D): 22}
# {(C, C): 12}
# {(C, C): 9}
# {(C, C): 17}
# player  5 states:
# {(D, C): 12}
# {(D, C): 1, (D, D): 9}
# {(D, C): 1, (D, D): 13}
# {(D, C): 22}
# {}
# {(D, C): 2, (D, D): 1}
# {(D, C): 4}
# {(D, C): 1}
# player  6 states:
# {(C, C): 20}
# {(C, C): 16}
# {(C, C): 21}
# {(C, C): 12}
# {(C, D): 2, (D, D): 1}
# {}
# {(C, C): 8}
# {(C, C): 21}
# player  7 states:
# {(C, C): 30}
# {(C, C): 3}
# {(C, C): 8}
# {(C, C): 9}
# {(C, D): 4}
# {(C, C): 8}
# {}
# {(C, C): 1}
# player  8 states:
# {(C, C): 2}
# {(C, C): 6}
# {(C, C): 6}
# {(C, C): 17}
# {(C, D): 1}
# {(C, C): 21}
# {(C, C): 1}
# {}
# The total number of CCs:  466
# str_list [('Cooperator', 'Grim Trigger', 'Tit For Tat', 'Fourteen Coop', 'Sucker Defect', 'Win-Stay Lose-Shift', 'Thirteen Coop', 'Bitter Cooperator')]
# team list: [('Cooperator', 'Grim Trigger', 'Tit For Tat', 'Fourteen Coop', 'Sucker Defect', 'Win-Stay Lose-Shift', 'Thirteen Coop', 'Bitter Cooperator')]
# str str: 2,4,6,3,12,7,5,1
# ***Processing number  1
# Save the data
# I am saving the data
# The file name is:  Data/Experiment2/ClassicPD_7C_Sucker_Defect_RPST_3_1_0_5.csv
# --- 0.6446423530578613 seconds ---

# %% [markdown]
# ### 7C + Sucker Defect results

# %%
classic_dataf = pd.read_csv('Data/Experiment2/ClassicPD_7C_Sucker_Defect_RPST_3_1_0_5.csv', index_col=0)

classic_dataf = classic_dataf.reset_index(drop=True)
classic_dataf.loc[:,:'SYS New CC Dist MIN']
# Out:
#           System ID  SYS MIN Score  SYS AVG Score  MIN of Team Avgs  \
# 0  2,4,6,3,12,7,5,1       2.571429       2.759184          2.759184
#
#    AVG of Team Mins  SYS CC Dist AVG  SYS CC Dist MIN  SYS New CC Dist AVG  \
# 0          2.571429             0.75             0.75             0.779264
#
#    SYS New CC Dist MIN
# 0             0.779264

# %%
with pd.option_context('display.max_rows', None, 'display.max_columns', None, 'display.max_colwidth', None):  # more options can be specified also
    display(classic_dataf[['System ID', 'Team1', 'Team1 Avg Score', 'Team1 New Avg Score', 
       'Team1 Min Score', 'Team1 Avg CC Dist', 'Team1 New Avg CC Dist']])
# Out:
#           System ID  \
# 0  2,4,6,3,12,7,5,1
#
#                                                                                                                                                                                                              Team1  \
# 0  Generic Memory One Player,Generic Memory One Player,Generic Memory One Player,Generic Memory One Player,Generic Memory One Player,Generic Memory One Player,Generic Memory One Player,Generic Memory One Player
#
#    Team1 Avg Score  Team1 New Avg Score  Team1 Min Score  Team1 Avg CC Dist  \
# 0         2.759184             5.548495         2.571429               0.75
#
#    Team1 New Avg CC Dist
# 0               0.779264

# %% [markdown]
# ### 7C + Two Defect (0, 0, 1, 0)

# %%
import axelrod as axl
players = ['Bitter Cooperator', 'Cooperator', 'Fourteen Coop', 'Grim Trigger', 'Thirteen Coop', 'Tit For Tat', 'Win-Stay Lose-Shift', 'Two Defect']
part_list = list(partitions(players,8))

p = Path('7_coop_Two_Defect.txt')
p.touch()
with open(p, "w") as f:
    json.dump(part_list, f)

# %%
print('Total count of teams: ',len(part_list))
print(part_list)
start_time = time.time()

print('Instantiate PD Experiments with different game types')
classic_pdExp = pd_exp.PdExp(part_list)

print('Running experiments and computing data')
classic_pdExp.run_experiments()

print('Save the data')
path = 'Data/Experiment2/'
classic_pdExp.save_data(path, 'ClassicPD_7C_Two_Defect')  # CHANGE file_name string when necessary

print("--- %s seconds ---" % (time.time() - start_time))
# Out:
# Total count of teams:  1
# [[('Cooperator', 'Grim Trigger', 'Tit For Tat', 'Fourteen Coop', 'Win-Stay Lose-Shift', 'Two Defect', 'Thirteen Coop', 'Bitter Cooperator')]]
# Instantiate PD Experiments with different game types
# Running experiments and computing data
# partition list:  [('Cooperator', 'Grim Trigger', 'Tit For Tat', 'Fourteen Coop', 'Win-Stay Lose-Shift', 'Two Defect', 'Thirteen Coop', 'Bitter Cooperator')]
# Instantiating tournament object with these players:  Generic Memory One Player,Generic Memory One Player,Generic Memory One Player,Generic Memory One Player,Generic Memory One Player,Generic Memory One Player,Generic Memory One Player,Generic Memory One Player
# Playing matches: 100%|██████████| 36/36 [00:00<00:00, 1739.43it/s]
# Analysing: 100%|██████████| 25/25 [00:00<00:00, 64.04it/s]
# Match length for each user against other users:  [[[3.0, 4.0, 8.0, 21.0, 12.0, 20.0, 30.0, 2.0], [4.0, 4.0, 6.0, 2.0, 10.0, 16.0, 3.0, 6.0], [8.0, 6.0, 2.0, 12.0, 14.0, 21.0, 8.0, 6.0], [21.0, 2.0, 12.0, 4.0, 22.0, 12.0, 9.0, 17.0], [12.0, 10.0, 14.0, 22.0, 4.0, 3.0, 4.0, 1.0], [20.0, 16.0, 21.0, 12.0, 3.0, 3.0, 8.0, 21.0], [30.0, 3.0, 8.0, 9.0, 4.0, 8.0, 6.0, 1.0], [2.0, 6.0, 6.0, 17.0, 1.0, 21.0, 1.0, 2.0]]]
# Counting the number of CC states:
# player  1 states:
# {}
# {(C, C): 4}
# {(C, C): 8}
# {(C, C): 21}
# {(C, C): 12}
# {(C, C): 10, (C, D): 10}
# {(C, C): 30}
# {(C, C): 2}
# player  2 states:
# {(C, C): 4}
# {}
# {(C, C): 6}
# {(C, C): 2}
# {(C, C): 10}
# {(C, D): 1, (D, C): 1, (D, D): 14}
# {(C, C): 3}
# {(C, C): 6}
# player  3 states:
# {(C, C): 8}
# {(C, C): 6}
# {}
# {(C, C): 12}
# {(C, C): 14}
# {(C, D): 11, (D, C): 10}
# {(C, C): 8}
# {(C, C): 6}
# player  4 states:
# {(C, C): 21}
# {(C, C): 2}
# {(C, C): 12}
# {}
# {(C, C): 22}
# {(C, C): 6, (C, D): 6}
# {(C, C): 9}
# {(C, C): 17}
# player  5 states:
# {(C, C): 12}
# {(C, C): 10}
# {(C, C): 14}
# {(C, C): 22}
# {}
# {(C, D): 1, (D, C): 1, (D, D): 1}
# {(C, C): 4}
# {(C, C): 1}
# player  6 states:
# {(C, C): 10, (D, C): 10}
# {(C, D): 1, (D, C): 1, (D, D): 14}
# {(C, D): 10, (D, C): 11}
# {(C, C): 6, (D, C): 6}
# {(C, D): 1, (D, C): 1, (D, D): 1}
# {}
# {(C, C): 4, (D, C): 4}
# {(C, D): 10, (D, C): 11}
# player  7 states:
# {(C, C): 30}
# {(C, C): 3}
# {(C, C): 8}
# {(C, C): 9}
# {(C, C): 4}
# {(C, C): 4, (C, D): 4}
# {}
# {(C, C): 1}
# player  8 states:
# {(C, C): 2}
# {(C, C): 6}
# {(C, C): 6}
# {(C, C): 17}
# {(C, C): 1}
# {(C, D): 11, (D, C): 10}
# {(C, C): 1}
# {}
# The total number of CCs:  436
# str_list [('Cooperator', 'Grim Trigger', 'Tit For Tat', 'Fourteen Coop', 'Win-Stay Lose-Shift', 'Two Defect', 'Thirteen Coop', 'Bitter Cooperator')]
# team list: [('Cooperator', 'Grim Trigger', 'Tit For Tat', 'Fourteen Coop', 'Win-Stay Lose-Shift', 'Two Defect', 'Thirteen Coop', 'Bitter Cooperator')]
# str str: 2,4,6,3,7,13,5,1
# ***Processing number  1
# Save the data
# I am saving the data
# The file name is:  Data/Experiment2/ClassicPD_7C_Two_Defect_RPST_3_1_0_5.csv
# --- 0.5534276962280273 seconds ---

# %% [markdown]
# ### 7C + Two Defect results

# %%
classic_dataf = pd.read_csv('Data/Experiment2/ClassicPD_7C_Two_Defect_RPST_3_1_0_5.csv', index_col=0)

classic_dataf = classic_dataf.reset_index(drop=True)
classic_dataf.loc[:,:'SYS New CC Dist MIN']
# Out:
#           System ID  SYS MIN Score  SYS AVG Score  MIN of Team Avgs  \
# 0  2,4,6,3,7,13,5,1       2.741071       2.837054          2.837054
#
#    AVG of Team Mins  SYS CC Dist AVG  SYS CC Dist MIN  SYS New CC Dist AVG  \
# 0          2.741071         0.803571         0.803571             0.729097
#
#    SYS New CC Dist MIN
# 0             0.729097

# %%
with pd.option_context('display.max_rows', None, 'display.max_columns', None, 'display.max_colwidth', None):  # more options can be specified also
    display(classic_dataf[['System ID', 'Team1', 'Team1 Avg Score', 'Team1 New Avg Score', 
       'Team1 Min Score', 'Team1 Avg CC Dist', 'Team1 New Avg CC Dist']])
# Out:
#           System ID  \
# 0  2,4,6,3,7,13,5,1
#
#                                                                                                                                                                                                              Team1  \
# 0  Generic Memory One Player,Generic Memory One Player,Generic Memory One Player,Generic Memory One Player,Generic Memory One Player,Generic Memory One Player,Generic Memory One Player,Generic Memory One Player
#
#    Team1 Avg Score  Team1 New Avg Score  Team1 Min Score  Team1 Avg CC Dist  \
# 0         2.837054             5.578595         2.741071           0.803571
#
#    Team1 New Avg CC Dist
# 0               0.729097

# %% [markdown]
# ### 7C + Win-Shift Lose-Stay (0, 1, 1, 0)

# %%
import axelrod as axl
players = ['Bitter Cooperator', 'Cooperator', 'Fourteen Coop', 'Grim Trigger', 'Thirteen Coop', 'Tit For Tat', 'Win-Stay Lose-Shift', 'Win-Shift Lose-Stay']
part_list = list(partitions(players,8))

p = Path('7_coop_Win-Shift_Lose-Stay.txt')
p.touch()
with open(p, "w") as f:
    json.dump(part_list, f)

# %%
print('Total count of teams: ',len(part_list))
print(part_list)
start_time = time.time()

print('Instantiate PD Experiments with different game types')
classic_pdExp = pd_exp.PdExp(part_list)

print('Running experiments and computing data')
classic_pdExp.run_experiments()

print('Save the data')
path = 'Data/Experiment2/'
classic_pdExp.save_data(path, 'ClassicPD_7C_Win-Shift_Lose-Stay')  # CHANGE file_name string when necessary

print("--- %s seconds ---" % (time.time() - start_time))
# Out:
# Total count of teams:  1
# [[('Cooperator', 'Grim Trigger', 'Tit For Tat', 'Fourteen Coop', 'Win-Stay Lose-Shift', 'Win-Shift Lose-Stay', 'Thirteen Coop', 'Bitter Cooperator')]]
# Instantiate PD Experiments with different game types
# Running experiments and computing data
# partition list:  [('Cooperator', 'Grim Trigger', 'Tit For Tat', 'Fourteen Coop', 'Win-Stay Lose-Shift', 'Win-Shift Lose-Stay', 'Thirteen Coop', 'Bitter Cooperator')]
# Instantiating tournament object with these players:  Generic Memory One Player,Generic Memory One Player,Generic Memory One Player,Generic Memory One Player,Generic Memory One Player,Generic Memory One Player,Generic Memory One Player,Generic Memory One Player
# Playing matches: 100%|██████████| 36/36 [00:00<00:00, 1021.06it/s]
# Analysing: 100%|██████████| 25/25 [00:00<00:00, 66.69it/s]
# Match length for each user against other users:  [[[3.0, 4.0, 8.0, 21.0, 12.0, 20.0, 30.0, 2.0], [4.0, 4.0, 6.0, 2.0, 10.0, 16.0, 3.0, 6.0], [8.0, 6.0, 2.0, 12.0, 14.0, 21.0, 8.0, 6.0], [21.0, 2.0, 12.0, 4.0, 22.0, 12.0, 9.0, 17.0], [12.0, 10.0, 14.0, 22.0, 4.0, 3.0, 4.0, 1.0], [20.0, 16.0, 21.0, 12.0, 3.0, 3.0, 8.0, 21.0], [30.0, 3.0, 8.0, 9.0, 4.0, 8.0, 6.0, 1.0], [2.0, 6.0, 6.0, 17.0, 1.0, 21.0, 1.0, 2.0]]]
# Counting the number of CC states:
# player  1 states:
# {}
# {(C, C): 4}
# {(C, C): 8}
# {(C, C): 21}
# {(C, C): 12}
# {(C, C): 10, (C, D): 10}
# {(C, C): 30}
# {(C, C): 2}
# player  2 states:
# {(C, C): 4}
# {}
# {(C, C): 6}
# {(C, C): 2}
# {(C, C): 10}
# {(C, D): 1, (D, C): 15}
# {(C, C): 3}
# {(C, C): 6}
# player  3 states:
# {(C, C): 8}
# {(C, C): 6}
# {}
# {(C, C): 12}
# {(C, C): 14}
# {(C, C): 7, (C, D): 7, (D, C): 7}
# {(C, C): 8}
# {(C, C): 6}
# player  4 states:
# {(C, C): 21}
# {(C, C): 2}
# {(C, C): 12}
# {}
# {(C, C): 22}
# {(C, C): 6, (C, D): 6}
# {(C, C): 9}
# {(C, C): 17}
# player  5 states:
# {(C, C): 12}
# {(C, C): 10}
# {(C, C): 14}
# {(C, C): 22}
# {}
# {(C, D): 1, (D, C): 2}
# {(C, C): 4}
# {(C, C): 1}
# player  6 states:
# {(C, C): 10, (D, C): 10}
# {(C, D): 15, (D, C): 1}
# {(C, C): 7, (C, D): 7, (D, C): 7}
# {(C, C): 6, (D, C): 6}
# {(C, D): 2, (D, C): 1}
# {}
# {(C, C): 4, (D, C): 4}
# {(C, C): 7, (C, D): 7, (D, C): 7}
# player  7 states:
# {(C, C): 30}
# {(C, C): 3}
# {(C, C): 8}
# {(C, C): 9}
# {(C, C): 4}
# {(C, C): 4, (C, D): 4}
# {}
# {(C, C): 1}
# player  8 states:
# {(C, C): 2}
# {(C, C): 6}
# {(C, C): 6}
# {(C, C): 17}
# {(C, C): 1}
# {(C, C): 7, (C, D): 7, (D, C): 7}
# {(C, C): 1}
# {}
# The total number of CCs:  464
# str_list [('Cooperator', 'Grim Trigger', 'Tit For Tat', 'Fourteen Coop', 'Win-Stay Lose-Shift', 'Win-Shift Lose-Stay', 'Thirteen Coop', 'Bitter Cooperator')]
# team list: [('Cooperator', 'Grim Trigger', 'Tit For Tat', 'Fourteen Coop', 'Win-Stay Lose-Shift', 'Win-Shift Lose-Stay', 'Thirteen Coop', 'Bitter Cooperator')]
# str str: 2,4,6,3,7,14,5,1
# ***Processing number  1
# Save the data
# I am saving the data
# The file name is:  Data/Experiment2/ClassicPD_7C_Win-Shift_Lose-Stay_RPST_3_1_0_5.csv
# --- 0.5483663082122803 seconds ---

# %% [markdown]
# ### 7C + Win-Shift Lose-Stay results

# %%
classic_dataf = pd.read_csv('Data/Experiment2/ClassicPD_7C_Win-Shift_Lose-Stay_RPST_3_1_0_5.csv', index_col=0)

classic_dataf = classic_dataf.reset_index(drop=True)
classic_dataf.loc[:,:'SYS New CC Dist MIN']
# Out:
#           System ID  SYS MIN Score  SYS AVG Score  MIN of Team Avgs  \
# 0  2,4,6,3,7,14,5,1       2.758929        2.91369           2.91369
#
#    AVG of Team Mins  SYS CC Dist AVG  SYS CC Dist MIN  SYS New CC Dist AVG  \
# 0          2.758929         0.827381         0.827381              0.77592
#
#    SYS New CC Dist MIN
# 0              0.77592

# %%
with pd.option_context('display.max_rows', None, 'display.max_columns', None, 'display.max_colwidth', None):  # more options can be specified also
    display(classic_dataf[['System ID', 'Team1', 'Team1 Avg Score', 'Team1 New Avg Score', 
       'Team1 Min Score', 'Team1 Avg CC Dist', 'Team1 New Avg CC Dist']])
# Out:
#           System ID  \
# 0  2,4,6,3,7,14,5,1
#
#                                                                                                                                                                                                              Team1  \
# 0  Generic Memory One Player,Generic Memory One Player,Generic Memory One Player,Generic Memory One Player,Generic Memory One Player,Generic Memory One Player,Generic Memory One Player,Generic Memory One Player
#
#    Team1 Avg Score  Team1 New Avg Score  Team1 Min Score  Team1 Avg CC Dist  \
# 0          2.91369              5.77592         2.758929           0.827381
#
#    Team1 New Avg CC Dist
# 0                0.77592

# %% [markdown]
# ### Total Results

# %%
classic_dataf = pd.read_csv('Data/Experiment2/7C1D_total.csv', index_col=0)

classic_dataf = classic_dataf.reset_index(drop=True)
classic_dataf.loc[:,:'SYS New CC Dist MIN']
# Out:
#                 System ID  SYS MIN Score  SYS AVG Score  MIN of Team Avgs  \
# 0                Defector       2.571429       2.730389          2.730389
# 1         Fourteen Defect       2.571429       2.937113          2.937113
# 2         Stubborn Defect       2.571429       2.730389          2.730389
# 3  Suspicious Tit For Tat       2.563180       2.859226          2.859226
# 4           Sucker Defect       2.571429       2.759184          2.759184
# 5              Two Defect       2.741071       2.837054          2.837054
# 6     Win-Shift Lose-Stay       2.758929       2.913690          2.913690
#
#    AVG of Team Mins  SYS CC Dist AVG  SYS CC Dist MIN  SYS New CC Dist AVG  \
# 0          2.571429         0.750000         0.750000             0.662207
# 1          2.571429         0.874227         0.874227             0.936455
# 2          2.571429         0.750000         0.750000             0.662207
# 3          2.563180         0.847917         0.847917             0.785953
# 4          2.571429         0.750000         0.750000             0.779264
# 5          2.741071         0.803571         0.803571             0.729097
# 6          2.758929         0.827381         0.827381             0.775920
#
#    SYS New CC Dist MIN
# 0             0.662207
# 1             0.936455
# 2             0.662207
# 3             0.785953
# 4             0.779264
# 5             0.729097
# 6             0.775920
